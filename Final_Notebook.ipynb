# %% [markdown]
# # Scouting restaurant locations in Toronto

# %% [markdown]
# <h2>Brief Description:</h2>
#
#     Here we tackle the problem of finding the most promising location to open a restaurant in a given city. There is no set in stone way of mathematically calculating "promise" or "potential" of any given location. As such, I intend to develop a model which calculates this attribute with some cadre of layman-ly sense. This will be achieved by inculcating every location's population, surface area, per capita income, pre-existing restaurants, etc. Ofcourse, one can include other parameters like each pre-existing restaurant's average rating, price range, number of likes, etc. However, since the purpose of this script is to provide a proof of concept, we will stick to parameters for which we only have to make regular calls to Foursquare, since premium calls on a personal account are very limited.

# %% [markdown]
# <h3> Import required libraries -

# %%
import numpy as np
import pandas as pd

# !pip -q install folium    # installing folium (used fro creating maps)
import folium

# %% [markdown]
# <h3> Read-in Toronto's demographic data -

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods')[1]
print(df.shape)
df.head()
# Out:
# (175, 13)
#                   Name    FM  \
# 0  Toronto CMA Average   NaN
# 1            Agincourt     S
# 2            Alderwood     E
# 3       Alexandra Park  OCoT
# 4              Allenby  OCoT
#
#                                        Census Tracts  Population  \
# 0                                                All     5113149
# 1  0377.01, 0377.02, 0377.03, 0377.04, 0378.02, 0...       44577
# 2                                   0211.00, 0212.00       11656
# 3                                            0039.00        4355
# 4                                            0140.00        2513
#
#    Land area (km2)  Density (people/km2)  % Change in Population since 2001  \
# 0          5903.63                   866                                9.0
# 1            12.45                  3580                                4.6
# 2             4.94                  2360                               -4.0
# 3             0.32                 13609                                0.0
# 4             0.58                  4333                               -1.0
#
#    Average Income  Transit Commuting %  % Renters  \
# 0           40704                 10.6       11.4
# 1           25750                 11.1        5.9
# 2           35239                  8.8        8.5
# 3           19687                 13.8       28.0
# 4          245592                  5.2        3.4
#
#   Second most common language (after English) by name  \
# 0                                                NaN
# 1                                  Cantonese (19.3%)
# 2                                      Polish (6.2%)
# 3                                  Cantonese (17.9%)
# 4                                     Russian (1.4%)
#
#   Second most common language (after English) by percentage  Map
# 0                                                NaN         NaN
# 1                                    19.3% Cantonese         NaN
# 2                                       06.2% Polish         NaN
# 3                                    17.9% Cantonese         NaN
# 4                                      01.4% Russian         NaN

# %%
df_new = df[['Name', 'Population', 'Land area (km2)', 'Density (people/km2)', 'Average Income']].reset_index()
df_new.drop(['index'], axis=1, inplace=True)
df_new.head()
# Out:
#                   Name  Population  Land area (km2)  Density (people/km2)  \
# 0  Toronto CMA Average     5113149          5903.63                   866
# 1            Agincourt       44577            12.45                  3580
# 2            Alderwood       11656             4.94                  2360
# 3       Alexandra Park        4355             0.32                 13609
# 4              Allenby        2513             0.58                  4333
#
#    Average Income
# 0           40704
# 1           25750
# 2           35239
# 3           19687
# 4          245592

# %%
df_new.shape
# Out:
# (175, 5)

# %% [markdown]
# <h3> Create a function to fetch coordinates of each neighborhood -

# %%
from geopy.geocoders import Nominatim    # used to find geographical coordinates  

def get_coordinates(names, code='TO'):
    
    coordinates = []    # list of all the (latitude, longitude) pairs
    empty_names=[]    # list of all the names for which geographical coordinates are not available
    
    for index, name in enumerate(names):
        name_ = name.split('/')
        address = '{}, {}'.format(name_[0], code)
        
        try:
            geolocator = Nominatim(user_agent="ny_explorer")
            location = geolocator.geocode(address)
            latitude = location.latitude
            longitude = location.longitude
            coordinates.append([latitude, longitude])
        except:
            print('Couldn\'t find coordinates for {}, index {}'.format(name, index))
            empty_names.append(name)
            
    return coordinates, empty_names

# %%
coordinates, empty_names = get_coordinates(names=df_new['Name'])
coordinates
# Out:
# Couldn't find coordinates for Toronto CMA Average, index 0
# Couldn't find coordinates for Humber Bay Shores, index 72
# Couldn't find coordinates for Humberlea, index 76
# Couldn't find coordinates for Humbermede, index 77
# Couldn't find coordinates for Pelmo Park, index 118
# Couldn't find coordinates for Playter Estates, index 119
# Couldn't find coordinates for Rockcliffe–Smythe, index 128
# Couldn't find coordinates for Tam O'Shanter – Sullivan, index 146
# [[43.7853531, -79.2785494],
#  [43.6017173, -79.5452325],
#  [43.650786999999994, -79.40431814731767],
#  [14.5953432, 121.0352197],
#  [42.8579536, -70.9300921],
#  [43.7439436, -79.4308512],
#  [52.0601807, -1.3402795],
#  [47.6271498, -65.648293],
#  [43.6673421, -79.3884571],
#  [43.7691966, -79.3766617],
#  [43.7981268, -79.3829726],
#  [43.7373876, -79.4109253],
#  [43.7535196, -79.2553355],
#  [43.6918051, -79.2644935],
#  [43.6493184, -79.4844358],
#  [43.6761954, -79.4280155],
#  [36.6411357, -93.2175285],
#  [43.7381512, -79.3725113],
#  [43.6509173, -79.4400216],
#  [43.6644734, -79.3669861],
#  [50.0163858, -114.89273791438612],
#  [43.6707006, -79.4532993],
#  [43.6781015, -79.409415775],
#  [43.7874914, -79.1507681],
#  [43.7025981, -79.4032704],
#  [43.6671385, -79.4227656],
#  [43.6655242, -79.3838011],
#  [48.2806809, -1.9758742],
#  [43.7088231, -79.2959856],
#  [43.7218363, -79.2362138],
#  [43.7111699, -79.2481769],
#  [43.6573699, -79.3565129],
#  [43.695403, -79.293099],
#  [42.3124161, -85.18514409429133],
#  [43.6715454, -79.4483222],
#  [43.697936, -79.3972908],
#  [43.68809, -79.3940935],
#  [43.6575555, -79.3894803],
#  [43.6502947, -79.3595401],
#  [43.775347, -79.3459439],
#  [43.7926732, -79.3547219],
#  [43.7528467, -79.282067],
#  [43.66522275, -79.43353744861585],
#  [43.7492988, -79.462248],
#  [43.6536319, -79.4264389],
#  [43.6762773, -79.4505723],
#  [40.820312, -87.977818],
#  [43.6462843, -79.5600005],
#  [43.7394646, -79.2320997],
#  [43.7572532, -79.5176975],
#  [43.6622732, -79.5765162],
#  [43.695689, -79.4503097],
#  [43.6454561, -79.3949942],
#  [43.64866395, -79.38153972121495],
#  [43.7184315, -79.333204],
#  [43.6935586, -79.4139023],
#  [43.63899205, -79.40344520868527],
#  [43.6564995, -79.3771141],
#  [43.7090016, -79.4437983],
#  [43.6894235, -79.3694257],
#  [43.652196599999996, -79.39231921757992],
#  [46.1935165, 6.587550409662679],
#  [43.7552251, -79.1982293],
#  [43.6615225, -79.4097446],
#  [43.6400801, -79.3801495],
#  [43.677044, -79.4761512],
#  [43.7695089, -79.354296],
#  [43.6573833, -79.470961],
#  [43.7901172, -79.1733344],
#  [55.7461001, -4.0526418],
#  [43.7415342, -79.4028781],
#  [43.6981789, -79.5232773],
#  [43.7600778, -79.5717598],
#  [43.6664717, -79.5243136],
#  [43.722525, -79.5460241478979],
#  [43.6902483, -79.4220973],
#  [43.7359904, -79.2765146],
#  [43.634539, -79.5192667],
#  [43.657898849999995, -79.44804324226126],
#  [43.6552136, -79.4022604],
#  [43.6995391, -79.5563459],
#  [43.6658675, -79.4992242],
#  [43.799003, -79.3059669],
#  [43.7589503, -79.4225555],
#  [43.7227784, -79.4509332],
#  [43.7220788, -79.4375067],
#  [43.729199, -79.4032525],
#  [43.7047983, -79.3680904],
#  [45.343638350000006, -75.62723268351955],
#  [43.6627, -79.3328148],
#  [-21.1272683, -175.2101314],
#  [43.64741325, -79.43111632546047],
#  [43.59200455, -79.54536450659592],
#  [43.7159986, -79.412291],
#  [43.8091955, -79.2217008],
#  [43.7122767, -79.4901977],
#  [53.5786159, -2.4809425],
#  [43.7590508, -79.3102297],
#  [43.8231743, -79.3017626],
#  [43.6166773, -79.4968048],
#  [43.6903876, -79.3832965],
#  [55.9296409, -3.2100796],
#  [43.6869597, -79.4895513],
#  [43.6007625, -79.505264],
#  [43.7938863, -79.42567902301055],
#  [43.6440753, -79.4086982],
#  [53.9590555, -1.0815361],
#  [43.6971738, -79.2748232],
#  [-35.28193565, 149.1116472376831],
#  [43.699971000000005, -79.33251996261595],
#  [43.649826, -79.4943338],
#  [43.6404954, -79.4368965],
#  [43.77166, -79.3426631],
#  [43.7587999, -79.3201966],
#  [43.787048, -79.3337137],
#  [43.6430648, -79.3506012],
#  [43.7755039, -79.1349765],
#  [51.4872382, -2.5494314],
#  [-38.12779465, 176.2372211514657],
#  [43.6607056, -79.3604569],
#  [43.688589, -79.5428473],
#  [43.6654704, -79.3525936],
#  [43.6514426, -79.4510381],
#  [43.6783556, -79.3807457],
#  [43.8049304, -79.1658374],
#  [43.7802711, -79.1304992],
#  [43.6517026, -79.4759978],
#  [43.7160494, -79.2607028],
#  [43.773077, -79.257774],
#  [43.7437422, -79.2116324],
#  [43.6692756, -79.4159596],
#  [43.682123, -79.4715724],
#  [56.5359461, -2.8436863],
#  [43.6779261, -79.4057671],
#  [43.6694032, -79.3727041],
#  [43.8161778, -79.3145378],
#  [43.6816776, -79.3905037],
#  [51.7425372, 0.0018064100339669658],
#  [43.64494, -79.478313],
#  [43.6703377, -79.407117],
#  [43.6710244, -79.296712],
#  [43.6864333, -79.3003555],
#  [55.9167295, -3.232597],
#  [43.6654775, -79.470352],
#  [43.6473811, -79.5113328],
#  [43.6236182, -79.5147637],
#  [43.7372656, -79.5653169],
#  [43.704553, -79.3454074],
#  [43.6230544, -79.39431563721035],
#  [43.64756465, -79.41388090266673],
#  [43.6784881, -79.31081921166198],
#  [43.732658, -79.3111892],
#  [43.6667328, -79.4464779],
#  [43.6631995, -79.5685684],
#  [43.7689144, -79.1872905],
#  [43.7859631, -79.1307556],
#  [39.8366528, -105.0372046],
#  [43.6936399, -79.5210426],
#  [43.7001608, -79.5162474],
#  [43.7453767, -79.2947155],
#  [43.7615095, -79.4109234],
#  [43.7405195, -79.4400172],
#  [43.7598243, -79.2252908],
#  [43.68217105, -79.423113155788],
#  [43.7440391, -79.406657],
#  [43.7587808, -79.5194336],
#  [43.6713861, -79.3901677]]

# %% [markdown]
# <h3> Remove the neighborhoods whose coordinates weren't available(i.e. empty_names) from df_new -

# %%
df_new.index = df['Name']
df_new.drop(index=empty_names, inplace=True)
df_new.drop(columns='Name', inplace=True)
df_new.head()
# Out:
#                 Population  Land area (km2)  Density (people/km2)  \
# Name
# Agincourt            44577            12.45                  3580
# Alderwood            11656             4.94                  2360
# Alexandra Park        4355             0.32                 13609
# Allenby               2513             0.58                  4333
# Amesbury             17318             3.51                  4934
#
#                 Average Income
# Name
# Agincourt                25750
# Alderwood                35239
# Alexandra Park           19687
# Allenby                 245592
# Amesbury                 27546

# %% [markdown]
# <h3> Sanity check: see whether the length of (coordinates) matches that of (df_new) -

# %%
print(len(coordinates))
print(df_new.shape)
# Out:
# 167
# (167, 4)

# %% [markdown]
# PHEW! ;-)

# %% [markdown]
# <h3> Add the coordinates data to (df_new) -

# %%
coordinates = np.array(coordinates)
latitudes = coordinates[:, 0]
longitudes = coordinates[:, 1]

# Create a dataframe with 2 columns, namely 'latitude' and 'longitude'
coords_df = pd.DataFrame({'latitude': latitudes, 'longitude': longitudes})
coords_df.index = df_new.index.values

# Combine (df_new) with (coords_df)
compiled_df = df_new.join(coords_df)
compiled_df.head()
# Out:
#                 Population  Land area (km2)  Density (people/km2)  \
# Name
# Agincourt            44577            12.45                  3580
# Alderwood            11656             4.94                  2360
# Alexandra Park        4355             0.32                 13609
# Allenby               2513             0.58                  4333
# Amesbury             17318             3.51                  4934
#
#                 Average Income   latitude   longitude
# Name
# Agincourt                25750  43.785353  -79.278549
# Alderwood                35239  43.601717  -79.545232
# Alexandra Park           19687  43.650787  -79.404318
# Allenby                 245592  14.595343  121.035220
# Amesbury                 27546  42.857954  -70.930092

# %%
compiled_df.shape
# Out:
# (167, 6)

# %% [markdown]
# <h3> Find the coordinates for Toronto itself -

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are ({}, {}).'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are (43.6534817, -79.3839347).

# %% [markdown]
# <h3> Create a pre-liminary map to show the location of each neighborhood in Toronto -

# %%
map_toronto = folium.Map(location=[latitude+0.05, longitude], zoom_start=10.75)    # center point of the map

for lat, lng, label in zip(compiled_df['latitude'], compiled_df['longitude'], compiled_df.index.values):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(    # attributes of each bubble in the map
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Sweet! Our job now is to gather information about restaurants in each neighborhood to find out which neighborhood presents the best "potential" to open up a new restaurant! For this purpose, we will need to use the Foursquare API. We will make only regular calls for the purpose of this project since premium calls are fairly limited on a personal account.

# %% [markdown]
# <h3> Enter Foursquare credentials -

# %%
CLIENT_ID = 'B0MWNNRJM5A4AEKPTTQKHDBWWAZF4MGKIESUMLTJOUPGQSED'    # Foursquare ID
CLIENT_SECRET = 'HH5LLRRQEEPEXL4FDETHRBNCFDCTQW5GIPVY5OY0NKONEIVW'    # Foursquare Secret
VERSION = '20200606' # Foursquare API version

# CLIENT_ID = 'QNXERFM0BE1Z3XS3KHHJMNH3VTF5MBGUJS4300ZR4ADDAVBP'
# CLIENT_SECRET = 'LXRLT31GCOPEJMSQZ40OGHKSKF2CPIRBYJZ3DBU1OW15K4NM'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: B0MWNNRJM5A4AEKPTTQKHDBWWAZF4MGKIESUMLTJOUPGQSED
# CLIENT_SECRET:HH5LLRRQEEPEXL4FDETHRBNCFDCTQW5GIPVY5OY0NKONEIVW

# %% [markdown]
# <h3> Create a function to make API requests for each location and return a dataframe with all the required data -

# %%
def get_category_type(row):    # unwrapping the results obtained from all the API requests 
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']


def getNearbyVenues(names, latitudes, longitudes, query_key, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&query={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            query_key,
            radius, 
            LIMIT)    # the API request URL
        
        results = requests.get(url).json()    
        venues = results['response']['venues']    # assign relevant part of JSON to venues

        dataframe = json_normalize(venues)    # tranform venues into a dataframe
        
        # keep only columns that include venue name, and anything that is associated with location
        try:
            filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
            dataframe_filtered = dataframe.loc[:, filtered_columns]
            #print(dataframe_filtered.head())
        except:
            continue
        
        # filter the category for each row
        dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

        # clean column names by keeping only last term
        dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
        
        frequency = dataframe_filtered.shape[0]    # number of restaurants in a given location
        dataframe_filtered['frequency'] = [frequency for i in range(frequency)]     
        dataframe_filtered['city'] = [name for i in range(frequency)]
        
        venues_list.append(dataframe_filtered)
    
    return pd.concat(venues_list)

# %% [markdown]
# <h3> Import libraries required by the function -

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %% [markdown]
# <h3> Call the 'getNearbyVenues' function to obtain all the required restaurant data -

# %%
query = 'restaurant'    # this will be our key word
toronto_venues = getNearbyVenues(names=compiled_df.index.values,
                                 latitudes=compiled_df['latitude'],
                                 longitudes=compiled_df['longitude'],
                                 query_key = query
                                )
toronto_venues.reset_index(inplace=True)
toronto_venues
# Out:
# Agincourt
# Alderwood
# Alexandra Park
# Allenby
# Amesbury
# Armour Heights
# Banbury
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods – Steeles
# Bedford Park
# Bendale
# Birch Cliff
# Bloor West Village
# Bracondale Hill
# Branson
# Bridle Path
# Brockton
# Cabbagetown
# Caribou Park
# Carleton Village
# Casa Loma
# Centennial
# Chaplin Estates
# Christie Pits
# Church and Wellesley
# Clairville
# Clairlea
# Cliffcrest
# Cliffside
# Corktown
# Crescent Town
# Cricket Club
# Davenport
# Davisville
# Deer Park
# Discovery District
# Distillery District/West Don Lands
# Don Mills
# Don Valley Village
# Dorset Park
# Dovercourt Park
# Downsview
# Dufferin Grove
# Earlscourt
# East Danforth
# Eatonville
# Eglinton East
# Elia (Jane and Finch)
# Eringate
# Fairbank
# Fashion District
# Financial District
# Flemingdon Park
# Forest Hill
# Fort York/Liberty Village
# Garden District
# Glen Park
# Governor's Bridge/Bennington Heights
# Grange Park
# Graydon Hall
# Guildwood
# Harbord Village
# Harbourfront / CityPlace
# Harwood
# Henry Farm
# High Park North
# Highland Creek
# Hillcrest
# Hoggs Hollow
# Humber Heights
# Humber Summit
# Humber Valley Village
# Humberwood
# Humewood–Cedarvale
# Ionview
# Islington – Six Points
# Junction Triangle
# Kensington Market
# Kingsview Village
# Lambton
# L'Amoreaux
# Lansing
# Lawrence Heights
# Lawrence Manor
# Lawrence Park
# Leaside
# Ledbury Park
# Leslieville
# Little Italy
# Little Portugal
# Long Branch
# Lytton Park
# Malvern
# Maple Leaf
# Markland Wood
# Maryvale
# Milliken
# Mimico
# Moore Park
# Morningside
# Mount Dennis
# New Toronto
# Newtonbrook
# Niagara
# North York City Centre
# Oakridge
# O'Connor–Parkview
# Old East York
# Old Mill/Baby Point
# Parkdale
# Parkway Forest
# Parkwoods
# Pleasant View
# Port Lands
# Port Union
# Princess Gardens
# Regal Heights
# Regent Park/Trefann Court
# Richview
# Riverdale
# Roncesvalles
# Rosedale
# Rouge
# Rouge Hill
# Runnymede
# Scarborough Junction
# Scarborough City Centre
# Scarborough Village
# Seaton Village
# Silverthorn
# Smithfield
# South Hill
# St. James Town
# Steeles
# Summerhill
# Sunnylea
# Swansea
# The Annex
# The Beaches
# The Danforth
# The Elms
# The Junction
# The Kingsway
# The Queensway
# Thistletown
# Thorncliffe Park
# Toronto Islands
# Trinity–Bellwoods
# Upper Beaches
# Victoria Village
# Wallace Emerson
# West Deane Park
# West Hill
# West Rouge
# Westminster
# Westmount
# Weston
# Wexford
# Willowdale
# Wilson Heights
# Woburn
# Wychwood
# York Mills
# York University Heights
# Yorkville
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:55: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#      index                          address                     categories  \
# 0        0             4271 Sheppard Ave. E             Chinese Restaurant
# 1        1               1 Glen Watford Dr.             Chinese Restaurant
# 2        2               9 Glen Watford Dr.              Korean Restaurant
# 3        3       25 Glen Watford Dr, Unit 9             Chinese Restaurant
# 4        4                              NaN             Chinese Restaurant
# 5        5    4227 Sheppard Ave, E. Unit B1           Cantonese Restaurant
# 6        6              4192 Sheppard Ave E             Chinese Restaurant
# 7        7      4227 Sheppard Ave E Unit B1           Cantonese Restaurant
# 8        8    4227 Sheppard Ave. E. Unit B2             Chinese Restaurant
# 9        9                              NaN               Asian Restaurant
# 10      10                              NaN         Peking Duck Restaurant
# 11      11               23 Glen Watford Dr                     Restaurant
# 12      12                  23 Glen Watford             Chinese Restaurant
# 13      13            23 Glen Watford Drive               Asian Restaurant
# 14      14       50 Weybright Court unit 32        South Indian Restaurant
# 15      15                              NaN           Cantonese Restaurant
# 16      16               8 Glen Watford Dr.           Hong Kong Restaurant
# 17      17              25 Glen Watford Dr.           Hong Kong Restaurant
# 18       0                  396 Browns Line                    Pizza Place
# 19       0               2A Kensington Ave.                 Breakfast Spot
# 20       1                   566 Queen St W                            Bar
# 21       2                 280 Spadina Ave.             Dim Sum Restaurant
# 22       3                  266 Spadina Ave                   Noodle House
# 23       4                  8 St Andrew St.              Korean Restaurant
# 24       5  261 Spadina Avenue. Upper level             Chinese Restaurant
# 25       6                          Denison  Vegetarian / Vegan Restaurant
# 26       7                   629 Queen St W           Kitchen Supply Store
# 27       8              638 Dundas St. West                           None
# 28       9                558 Queen St West           Caribbean Restaurant
# 29      10               598 Queen St. West                          Diner
# ..     ...                              ...                            ...
# 726      1                              NaN                           None
# 727      2            778 St Clair Ave West              Indian Restaurant
# 728      0                              NaN                          Diner
# 729      0            100 Cumberland Street                    Event Space
# 730      1                116 Yorkville Ave        New American Restaurant
# 731      2                     90 Bloor St.                     Restaurant
# 732      3              69 Yorkville Avenue             Italian Restaurant
# 733      4                84 Yorkville Ave.        New American Restaurant
# 734      5                   24 Bellair St.            Japanese Restaurant
# 735      6                  1240 Bay Street                     Restaurant
# 736      7                 12 Cumberland St              Indian Restaurant
# 737      8       1 Spadina Road, Unit 25-29             Chinese Restaurant
# 738      9                  303 Augusta Ave              Indian Restaurant
# 739     10            154 Cumberland Street            Japanese Restaurant
# 740     11              69 Yorkville Avenue             Dim Sum Restaurant
# 741     12                    55 Bloor St W             Italian Restaurant
# 742     13                     689 Yonge St               Sushi Restaurant
# 743     14             119 Yorkville Avenue                   Cocktail Bar
# 744     15                     90 Avenue Rd             Chinese Restaurant
# 745     16               200 Bloor St. West             Chinese Restaurant
# 746     17                17 Yorkville Ave.             Italian Restaurant
# 747     18                 848 Yonge Street                 Sandwich Place
# 748     19                      1102 Bay St                 Sandwich Place
# 749     20                 120 Bloor St. E.                 Breakfast Spot
# 750     21               142 Cumberland St.                     Restaurant
# 751     22                     932 Yonge St                 Sandwich Place
# 752     23            154 Cumberland Street                          Hotel
# 753     24                   820 Church St.              Indian Restaurant
# 754     25                   200 Bloor St W                 Sandwich Place
# 755     26                      Charles St.            Japanese Restaurant
#
#      cc            city country                                crossStreet  \
# 0    CA       Agincourt  Canada                btwn Brimley & Midland Ave.
# 1    CA       Agincourt  Canada                                        NaN
# 2    CA       Agincourt  Canada                         at Sheppard Ave. E
# 3    CA       Agincourt  Canada                          at Sheppard Ave E
# 4    CA       Agincourt  Canada                                        NaN
# 5    CA       Agincourt  Canada                                Midland Ave
# 6    CA       Agincourt  Canada                             at Midland Ave
# 7    CA       Agincourt  Canada                                        NaN
# 8    CA       Agincourt  Canada                                        NaN
# 9    CA       Agincourt  Canada                                        NaN
# 10   CA       Agincourt  Canada                                        NaN
# 11   CA       Agincourt  Canada                                        NaN
# 12   CA       Agincourt  Canada                                        NaN
# 13   CA       Agincourt  Canada  Sheppard Avenue East & Glen Watford Drive
# 14   CA       Agincourt  Canada                                        NaN
# 15   CA       Agincourt  Canada                                        NaN
# 16   CA       Agincourt  Canada                         at Sheppard Ave. E
# 17   CA       Agincourt  Canada                         at Sheppard Ave. E
# 18   CA       Alderwood  Canada                              at Horner Ave
# 19   CA  Alexandra Park  Canada                               Dundas St. W
# 20   CA  Alexandra Park  Canada                                        NaN
# 21   CA  Alexandra Park  Canada                           at Dundas St. W.
# 22   CA  Alexandra Park  Canada                             at Willison Sq
# 23   CA  Alexandra Park  Canada                            at Spadina Ave.
# 24   CA  Alexandra Park  Canada                                        NaN
# 25   CA  Alexandra Park  Canada                               Dundas St. W
# 26   CA  Alexandra Park  Canada                            Bathurst Street
# 27   CA  Alexandra Park  Canada                                    Denison
# 28   CA  Alexandra Park  Canada                                        NaN
# 29   CA  Alexandra Park  Canada                                   Bathurst
# ..   ..             ...     ...                                        ...
# 726  CA        Wychwood  Canada                                        NaN
# 727  CA        Wychwood  Canada              St Clair West & Arlington Ave
# 728  CA      York Mills  Canada                                        NaN
# 729  CA       Yorkville  Canada                                 Bellair St
# 730  CA       Yorkville  Canada                           at Hazelton Ave.
# 731  CA       Yorkville  Canada                                  Yonge St.
# 732  CA       Yorkville  Canada                                     at Bay
# 733  CA       Yorkville  Canada                                        NaN
# 734  CA       Yorkville  Canada                                        NaN
# 735  CA       Yorkville  Canada                                        NaN
# 736  CA       Yorkville  Canada                                   Yonge St
# 737  CA       Yorkville  Canada                                        NaN
# 738  CA       Yorkville  Canada                                        NaN
# 739  CA       Yorkville  Canada                                        NaN
# 740  CA       Yorkville  Canada                                        NaN
# 741  CA       Yorkville  Canada                                        NaN
# 742  CA       Yorkville  Canada                              at Charles St
# 743  CA       Yorkville  Canada                                        NaN
# 744  CA       Yorkville  Canada                                        NaN
# 745  CA       Yorkville  Canada                    btw Avenue & St. George
# 746  CA       Yorkville  Canada                                      Yonge
# 747  CA       Yorkville  Canada                            @ Yorkville Ave
# 748  CA       Yorkville  Canada                             at St. Mary St
# 749  CA       Yorkville  Canada                                at Park Rd.
# 750  CA       Yorkville  Canada                   btw Avenue Rd. & Bay St.
# 751  CA       Yorkville  Canada                                    Belmont
# 752  CA       Yorkville  Canada                                        NaN
# 753  CA       Yorkville  Canada                               at Yonge St.
# 754  CA       Yorkville  Canada                              at Bedford Rd
# 755  CA       Yorkville  Canada                               at Yonge St.
#
#      distance                                   formattedAddress  frequency  \
# 0         212  [4271 Sheppard Ave. E (btwn Brimley & Midland ...         18
# 1         247       [1 Glen Watford Dr., Scarborough ON, Canada]         18
# 2         260  [9 Glen Watford Dr. (at Sheppard Ave. E), Scar...         18
# 3         314  [25 Glen Watford Dr, Unit 9 (at Sheppard Ave E...         18
# 4          55                                           [Canada]         18
# 5          64  [4227 Sheppard Ave, E. Unit B1 (Midland Ave), ...         18
# 6          74  [4192 Sheppard Ave E (at Midland Ave), Scarbor...         18
# 7         106  [4227 Sheppard Ave E Unit B1, Scarborough ON, ...         18
# 8         114  [4227 Sheppard Ave. E. Unit B2, Scarborough ON...         18
# 9         156                                           [Canada]         18
# 10        242                                           [Canada]         18
# 11        389       [23 Glen Watford Dr, Toronto ON M1S, Canada]         18
# 12        357              [23 Glen Watford, Toronto ON, Canada]         18
# 13        405  [23 Glen Watford Drive (Sheppard Avenue East &...         18
# 14        426  [50 Weybright Court unit 32, Toronto Division ...         18
# 15        465                                           [Canada]         18
# 16        193  [8 Glen Watford Dr. (at Sheppard Ave. E), Toro...         18
# 17        287  [25 Glen Watford Dr. (at Sheppard Ave. E), Sca...         18
# 18         51  [396 Browns Line (at Horner Ave), Etobicoke ON...          1
# 19        416  [2A Kensington Ave. (Dundas St. W), Toronto ON...         25
# 20        394               [566 Queen St W, Toronto ON, Canada]         25
# 21        542  [280 Spadina Ave. (at Dundas St. W.), Toronto ...         25
# 22        532  [266 Spadina Ave (at Willison Sq), Toronto ON ...         25
# 23        564  [8 St Andrew St. (at Spadina Ave.), Toronto ON...         25
# 24        580  [261 Spadina Avenue. Upper level, Toronto ON M...         25
# 25        208       [Denison (Dundas St. W), Toronto ON, Canada]         25
# 26        390  [629 Queen St W (Bathurst Street), Toronto ON ...         25
# 27        208  [638 Dundas St. West (Denison), Toronto ON, Ca...         25
# 28        388            [558 Queen St West, Toronto ON, Canada]         25
# 29        395  [598 Queen St. West (Bathurst), Toronto ON, Ca...         25
# ..        ...                                                ...        ...
# 726       244                               [Toronto ON, Canada]          3
# 727       504  [778 St Clair Ave West (St Clair West & Arling...          3
# 728       251                                           [Canada]          1
# 729       135  [100 Cumberland Street (Bellair St), Toronto O...         27
# 730       258  [116 Yorkville Ave (at Hazelton Ave.), Toronto...         27
# 731       437  [90 Bloor St. (Yonge St.), Toronto ON M4W 1A7,...         27
# 732        62  [69 Yorkville Avenue (at Bay), Toronto ON M5R ...         27
# 733       110    [84 Yorkville Ave., Toronto ON M5R 1B9, Canada]         27
# 734       105       [24 Bellair St., Toronto ON M5R 2C7, Canada]         27
# 735       111      [1240 Bay Street, Toronto ON M5R 3N7, Canada]         27
# 736       182  [12 Cumberland St (Yonge St), Toronto ON, Canada]         27
# 737       237               [1 Spadina Road, Unit 25-29, Canada]         27
# 738       253              [303 Augusta Ave, Toronto ON, Canada]         27
# 739       294  [154 Cumberland Street, Toronto ON M5R 1A8, Ca...         27
# 740        59          [69 Yorkville Avenue, Toronto ON, Canada]         27
# 741       325        [55 Bloor St W, Toronto ON M4W 1A5, Canada]         27
# 742       416  [689 Yonge St (at Charles St), Toronto ON M4Y ...         27
# 743       242  [119 Yorkville Avenue, Toronto ON M5R 1C4, Can...         27
# 744       460                 [90 Avenue Rd, Toronto ON, Canada]         27
# 745       535  [200 Bloor St. West (btw Avenue & St. George),...         27
# 746       129  [17 Yorkville Ave. (Yonge), Toronto ON M4W 1L1...         27
# 747       208  [848 Yonge Street (@ Yorkville Ave), Toronto O...         27
# 748       441  [1102 Bay St (at St. Mary St), Toronto ON M5S ...         27
# 749       484  [120 Bloor St. E. (at Park Rd.), Toronto ON M4...         27
# 750       253  [142 Cumberland St. (btw Avenue Rd. & Bay St.)...         27
# 751       359  [932 Yonge St (Belmont), Toronto ON M4W 2J2, C...         27
# 752       293  [154 Cumberland Street, Toronto ON M5R 1A8, Ca...         27
# 753       360  [820 Church St. (at Yonge St.), Toronto ON M4W...         27
# 754       536  [200 Bloor St W (at Bedford Rd), Toronto ON M5...         27
# 755       497   [Charles St. (at Yonge St.), Toronto ON, Canada]         27
#
#                            id  \
# 0    4be303c52fc7d13ae879083a
# 1    4baa46def964a520485a3ae3
# 2    4d2f8a98789a8cfa6b0826c6
# 3    53dbb77e498e6dfadda043fa
# 4    4f3852b7e4b0ea2d7edc00ca
# 5    5647afde498e42030b40c86d
# 6    54838447498e2f5b90530813
# 7    53489594498e2802cb19ddca
# 8    5d80fe5ba86ac4000795406a
# 9    4d2bbbf3888af04db4abe2af
# 10   564fbc10498e317227340ab1
# 11   4d2b495d6e27a143be653624
# 12   4b2f7fb2f964a520d3eb24e3
# 13   4e13471a8877ac23b67131df
# 14   4c54a130f5f3d13ab41070fa
# 15   550225c3498e887caf37f7be
# 16   51d84f68498e20fcf16c13d9
# 17   4bb74fea1344b7136f8e9e04
# 18   4c47927c1ddec928fbec9d32
# 19   4bce1ec0cc8cd13a9ac8c3cf
# 20   4c47d78c1ddec92817ca9e32
# 21   4b072e9df964a52009f922e3
# 22   4b266f05f964a520657b24e3
# 23   4ba2d00cf964a5203e1b38e3
# 24   5c33c7cd8194fc002c66f72e
# 25   4cb79089dd41a35d6a2fd4a0
# 26   4cdee51278ddf04d0a7c9d98
# 27   4b8171a1f964a5205da630e3
# 28   4b6e3f5ef964a52021b42ce3
# 29   4ba64368f964a520684039e3
# ..                        ...
# 726  5561802a498e00cae8804d5e
# 727  52418b0b7e48222eea81d2d2
# 728  4d5ab9013281b1f7fe01c92f
# 729  4ad4c05cf964a520cef520e3
# 730  4b02a076f964a520234922e3
# 731  4b4d3b51f964a520e4ce26e3
# 732  4addf19ef964a520916621e3
# 733  4d35c67e97fa5941b5ba603e
# 734  4ad4c05ff964a5203af720e3
# 735  580aea74d67c230d453b04aa
# 736  5605d124498e0f46d602ee3a
# 737  4d1a8e03dd363704e88d5c1a
# 738  4e7e17295503d17f912287fc
# 739  4ad4c060f964a52062f720e3
# 740  4d0d035a903d37042c51c155
# 741  4adcc289f964a520812f21e3
# 742  4adc9ad8f964a520ce2d21e3
# 743  4ad4c05df964a52042f620e3
# 744  4b5e3cc6f964a5207b8529e3
# 745  4b880a37f964a5200cdb31e3
# 746  4b737d37f964a520f6b02de3
# 747  4c0d6173e60fb713bf502122
# 748  4c0e3ec52466a59312b07821
# 749  4d260aa45cc1a093cd6b98be
# 750  4ad4c05df964a52054f620e3
# 751  4bbf6dfc30c99c74fe2e5511
# 752  4ae1cb55f964a520758721e3
# 753  4afa45ddf964a5209b1722e3
# 754  4c17c9f02cddb7134f0b831e
# 755  4ae787b9f964a52020ac21e3
#
#                                         labeledLatLngs        lat        lng  \
# 0    [{'label': 'display', 'lat': 43.78593747713555...  43.785937 -79.276031
# 1    [{'label': 'display', 'lat': 43.78620976205095...  43.786210 -79.275701
# 2    [{'label': 'display', 'lat': 43.78646767038441...  43.786468 -79.275693
# 3    [{'label': 'display', 'lat': 43.78707762430626...  43.787078 -79.275454
# 4    [{'label': 'display', 'lat': 43.78489781410844...  43.784898 -79.278272
# 5    [{'label': 'display', 'lat': 43.78508719298561...  43.785087 -79.277843
# 6    [{'label': 'display', 'lat': 43.78516372850498...  43.785164 -79.279433
# 7    [{'label': 'display', 'lat': 43.78472450642784...  43.784725 -79.277556
# 8    [{'label': 'display', 'lat': 43.78451273285425...  43.784513 -79.277735
# 9    [{'label': 'display', 'lat': 43.78582201864889...  43.785822 -79.276714
# 10   [{'label': 'display', 'lat': 43.78617895822158...  43.786179 -79.275756
# 11   [{'label': 'display', 'lat': 43.78693261153702...  43.786933 -79.274230
# 12   [{'label': 'display', 'lat': 43.7870663001502,...  43.787066 -79.274782
# 13   [{'label': 'display', 'lat': 43.78689596410336...  43.786896 -79.273973
# 14   [{'label': 'display', 'lat': 43.781806, 'lng':...  43.781806 -79.276560
# 15   [{'label': 'display', 'lat': 43.78570022312909...  43.785700 -79.284316
# 16   [{'label': 'display', 'lat': 43.78677856611482...  43.786779 -79.277179
# 17   [{'label': 'display', 'lat': 43.78710781967966...  43.787108 -79.275931
# 18   [{'label': 'display', 'lat': 43.60128, 'lng': ...  43.601280 -79.545028
# 19   [{'label': 'display', 'lat': 43.65280330843737...  43.652803 -79.399958
# 20   [{'label': 'display', 'lat': 43.64728932229506...  43.647289 -79.403493
# 21   [{'label': 'display', 'lat': 43.65278331265585...  43.652783 -79.398174
# 22   [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
# 23   [{'label': 'display', 'lat': 43.65430655228665...  43.654307 -79.399277
# 24   [{'label': 'display', 'lat': 43.65248783033554...  43.652488 -79.397501
# 25   [{'label': 'display', 'lat': 43.65203370402621...  43.652034 -79.402382
# 26   [{'label': 'display', 'lat': 43.647378, 'lng':...  43.647378 -79.403165
# 27   [{'label': 'display', 'lat': 43.652131, 'lng':...  43.652131 -79.402520
# 28   [{'label': 'display', 'lat': 43.64738643913458...  43.647386 -79.403210
# 29   [{'label': 'display', 'lat': 43.647233, 'lng':...  43.647233 -79.404508
# ..                                                 ...        ...        ...
# 726  [{'label': 'display', 'lat': 43.683081, 'lng':...  43.683081 -79.420353
# 727  [{'label': 'display', 'lat': 43.68105502412986...  43.681055 -79.429187
# 728  [{'label': 'display', 'lat': 43.74629628341726...  43.746296 -79.406698
# 729  [{'label': 'display', 'lat': 43.67034226367314...  43.670342 -79.391041
# 730  [{'label': 'display', 'lat': 43.67080936827553...  43.670809 -79.393272
# 731  [{'label': 'display', 'lat': 43.67057375344845...  43.670574 -79.384856
# 732  [{'label': 'display', 'lat': 43.671073, 'lng':...  43.671073 -79.390808
# 733  [{'label': 'display', 'lat': 43.67105534505626...  43.671055 -79.391458
# 734  [{'label': 'display', 'lat': 43.67068330431913...  43.670683 -79.391056
# 735  [{'label': 'display', 'lat': 43.6704210468, 'l...  43.670421 -79.389793
# 736  [{'label': 'display', 'lat': 43.67102313867917...  43.671023 -79.387957
# 737  [{'label': 'display', 'lat': 43.67045, 'lng': ...  43.670450 -79.392822
# 738  [{'label': 'display', 'lat': 43.67013, 'lng': ...  43.670130 -79.392800
# 739  [{'label': 'display', 'lat': 43.66993425275334...  43.669934 -79.393227
# 740  [{'label': 'display', 'lat': 43.67114125499929...  43.671141 -79.390827
# 741  [{'label': 'display', 'lat': 43.66879380295752...  43.668794 -79.388296
# 742  [{'label': 'display', 'lat': 43.6689434910527,...  43.668943 -79.386241
# 743  [{'label': 'display', 'lat': 43.67040702867929...  43.670407 -79.392853
# 744  [{'label': 'display', 'lat': 43.672401, 'lng':...  43.672401 -79.395712
# 745  [{'label': 'display', 'lat': 43.66838255236472...  43.668383 -79.395363
# 746  [{'label': 'display', 'lat': 43.67168516880110...  43.671685 -79.388614
# 747  [{'label': 'display', 'lat': 43.67165639708646...  43.671656 -79.387610
# 748  [{'label': 'display', 'lat': 43.66752691678821...  43.667527 -79.388919
# 749  [{'label': 'display', 'lat': 43.67080880788391...  43.670809 -79.384200
# 750  [{'label': 'display', 'lat': 43.67008065655273...  43.670081 -79.392744
# 751  [{'label': 'display', 'lat': 43.67443833074628...  43.674438 -79.388703
# 752  [{'label': 'display', 'lat': 43.670009, 'lng':...  43.670009 -79.393281
# 753  [{'label': 'display', 'lat': 43.67221373713898...  43.672214 -79.385843
# 754  [{'label': 'display', 'lat': 43.66842331002552...  43.668423 -79.395421
# 755  [{'label': 'display', 'lat': 43.66878262373862...  43.668783 -79.385153
#
#                                                 name neighborhood postalCode  \
# 0                       Beef Noodle Restaurant 老李牛肉麵          NaN    M1S 4G4
# 1          South Sea Fish Village Chinese Restaurant          NaN        NaN
# 2    In Cheon House Korean & Japanese Restaurant 인천관          NaN    M1S 2B9
# 3                Old Neighbour Restaurant 老街坊天津韩记包子铺          NaN    M1S 2B7
# 4                             Lucky House Restaurant          NaN        NaN
# 5                      King Huang Chinese Restaurant          NaN    M1S 5H5
# 6                  Tianjin Dumpling Restaurant 天津包子铺          NaN    M1S 1T3
# 7                                 Ox Land Restaurant          NaN        NaN
# 8                  May Yan Seafood Restaurant 陸福海鮮酒家          NaN    M1S 5H5
# 9                              pengfuxuan Restaurant          NaN        NaN
# 10                      Peking Duck Restaurant 北京烤鸭店          NaN        NaN
# 11                            Grand Ocean Restaurant          NaN        M1S
# 12              Scarborough Grand Seafood Restaurant          NaN        NaN
# 13                   Ocean Castle Seafood Restaurant          NaN    M1S 2B7
# 14                              Motimahal Restaurant          NaN        NaN
# 15                              King Hung restaurant          NaN        NaN
# 16                                 Cousin Cafe 表哥茶餐廳          NaN    M1S 2C1
# 17                               Fisherman Villa 褔臨門          NaN    M1S 2B7
# 18                  Il Paesano Pizzeria & Restaurant          NaN    M8W 3T8
# 19                 Kensington Cornerstone Restaurant          NaN    M5T 2J7
# 20                     Micheal's Restaurant and Deli          NaN        NaN
# 21                Sky Dragon Chinese Restaurant 龍翔酒樓          NaN        NaN
# 22                    Goldstone Noodle Restaurant 金石          NaN    M5T 2E4
# 23                          Ka Chi Korean Restaurant          NaN    M5T 1K6
# 24                     Green Tea Restaurant Downtown          NaN    M5T 2E3
# 25                      Greens Vegetarian Restaurant          NaN        NaN
# 26                     Nikolaou Restaurant Equipment          NaN    M5V 2B7
# 27                   Full Moon Vegetarian Restaurant          NaN        NaN
# 28               Pat's Homestyle Jamaican Restaurant          NaN        NaN
# 29                                   Barn Restaurant          NaN        NaN
# ..                                               ...          ...        ...
# 726                                 Bloom Restaurant          NaN        NaN
# 727                                 Pukka Restaurant          NaN    M6C 1B6
# 728                           Garden Deli Restaurant          NaN        NaN
# 729   Sassafraz | Cafe | Restaurant | Private Events    Yorkville    M5R 1A6
# 730                            ONE Restaurant/Lounge          NaN        NaN
# 731                       Matisse Restaurant And Bar          NaN    M4W 1A7
# 732                                  True Restaurant          NaN    M5R 1B8
# 733                                Sorrel Restaurant          NaN    M5R 1B9
# 734                       Yamato Japanese Restaurant          NaN    M5R 2C7
# 735                              Brothers Restaurant    Yorkville    M5R 3N7
# 736                             Kathmandu Restaurant          NaN        NaN
# 737                      Regal 16 Chinese Restaurant          NaN        NaN
# 738                            Waterfalls restaurant          NaN        NaN
# 739                       Shogun Japanese Restaurant          NaN    M5R 1A8
# 740                          Dynasty Chinese Cuisine          NaN        NaN
# 741                               Scaccia Restaurant          NaN    M4W 1A5
# 742                                   OJA Restaurant          NaN    M4Y 2B2
# 743                           Amber Restaurant & Bar          NaN    M5R 1C4
# 744                                   Zin Restaurant          NaN        NaN
# 745                          China Garden Restaurant          NaN   M5S 1T8‎
# 746                        Blu Ristorante and Lounge          NaN    M4W 1L1
# 747                                           Subway          NaN    M4W 2H1
# 748                                           Subway          NaN    M5S 2Y1
# 749                                     Sunset Grill          NaN    M4W 3R9
# 750                                      Hemingway's          NaN    M5R 1A8
# 751                                           Subway          NaN    M4W 2J2
# 752           Toronto Marriott Bloor Yorkville Hotel          NaN    M5R 1A8
# 753                                    King's Palace          NaN    M4W 2M9
# 754                                           Subway          NaN    M5S 1T8
# 755                                    Tokyo Kitchen          NaN        NaN
#
#     state
# 0      ON
# 1      ON
# 2      ON
# 3      ON
# 4     NaN
# 5      ON
# 6      ON
# 7      ON
# 8      ON
# 9     NaN
# 10    NaN
# 11     ON
# 12     ON
# 13     ON
# 14     ON
# 15    NaN
# 16     ON
# 17     ON
# 18     ON
# 19     ON
# 20     ON
# 21     ON
# 22     ON
# 23     ON
# 24     ON
# 25     ON
# 26     ON
# 27     ON
# 28     ON
# 29     ON
# ..    ...
# 726    ON
# 727    ON
# 728   NaN
# 729    ON
# 730    ON
# 731    ON
# 732    ON
# 733    ON
# 734    ON
# 735    ON
# 736    ON
# 737   NaN
# 738    ON
# 739    ON
# 740    ON
# 741    ON
# 742    ON
# 743    ON
# 744    ON
# 745    ON
# 746    ON
# 747    ON
# 748    ON
# 749    ON
# 750    ON
# 751    ON
# 752    ON
# 753    ON
# 754    ON
# 755    ON
#
# [756 rows x 18 columns]

# %% [markdown]
# <h3> Wrangle the above obtained dataframe and find out the number of restaurants in each neighborhood -

# %%
columns = ['name', 'city', 'categories', 'lat', 'lng', 'id', 'frequency']
toronto_venues = toronto_venues[columns]
print(toronto_venues['city'].value_counts())
# Out:
# Grange Park                             48
# Kensington Market                       41
# Financial District                      37
# Garden District                         36
# Discovery District                      30
# Fashion District                        29
# Bay Street Corridor                     29
# Yorkville                               27
# Alexandra Park                          25
# Church and Wellesley                    21
# Harbord Village                         20
# North York City Centre                  19
# Agincourt                               18
# Harbourfront / CityPlace                14
# Milliken                                13
# Niagara                                 11
# Christie Pits                           11
# Newtonbrook                             10
# Don Valley Village                       9
# Lawrence Park                            8
# Cabbagetown                              8
# Parkdale                                 8
# Chaplin Estates                          8
# Allenby                                  8
# Willowdale                               7
# Flemingdon Park                          7
# Dufferin Grove                           7
# Banbury                                  7
# St. James Town                           7
# Riverdale                                7
#                                         ..
# Glen Park                                2
# Maryvale                                 2
# Islington – Six Points                   2
# Scarborough Junction                     2
# High Park North                          1
# Guildwood                                1
# Lawrence Manor                           1
# Wallace Emerson                          1
# The Junction                             1
# Parkway Forest                           1
# Westminster                              1
# York Mills                               1
# Eringate                                 1
# Alderwood                                1
# Brockton                                 1
# Downsview                                1
# Old Mill/Baby Point                      1
# Bracondale Hill                          1
# Kingsview Village                        1
# Don Mills                                1
# Parkwoods                                1
# The Kingsway                             1
# Lambton                                  1
# Cliffcrest                               1
# Port Lands                               1
# Scarborough City Centre                  1
# Swansea                                  1
# Humewood–Cedarvale                       1
# Governor's Bridge/Bennington Heights     1
# Little Italy                             1
# Name: city, Length: 116, dtype: int64

# %%
# Wrangling continued...
all_venues = toronto_venues.iloc[:, :]
all_venues.reset_index(inplace=True)
all_venues.drop(columns='index', inplace=True)
all_venues
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                                                 name            city  \
# 0                       Beef Noodle Restaurant 老李牛肉麵       Agincourt
# 1          South Sea Fish Village Chinese Restaurant       Agincourt
# 2    In Cheon House Korean & Japanese Restaurant 인천관       Agincourt
# 3                Old Neighbour Restaurant 老街坊天津韩记包子铺       Agincourt
# 4                             Lucky House Restaurant       Agincourt
# 5                      King Huang Chinese Restaurant       Agincourt
# 6                  Tianjin Dumpling Restaurant 天津包子铺       Agincourt
# 7                                 Ox Land Restaurant       Agincourt
# 8                  May Yan Seafood Restaurant 陸福海鮮酒家       Agincourt
# 9                              pengfuxuan Restaurant       Agincourt
# 10                      Peking Duck Restaurant 北京烤鸭店       Agincourt
# 11                            Grand Ocean Restaurant       Agincourt
# 12              Scarborough Grand Seafood Restaurant       Agincourt
# 13                   Ocean Castle Seafood Restaurant       Agincourt
# 14                              Motimahal Restaurant       Agincourt
# 15                              King Hung restaurant       Agincourt
# 16                                 Cousin Cafe 表哥茶餐廳       Agincourt
# 17                               Fisherman Villa 褔臨門       Agincourt
# 18                  Il Paesano Pizzeria & Restaurant       Alderwood
# 19                 Kensington Cornerstone Restaurant  Alexandra Park
# 20                     Micheal's Restaurant and Deli  Alexandra Park
# 21                Sky Dragon Chinese Restaurant 龍翔酒樓  Alexandra Park
# 22                    Goldstone Noodle Restaurant 金石  Alexandra Park
# 23                          Ka Chi Korean Restaurant  Alexandra Park
# 24                     Green Tea Restaurant Downtown  Alexandra Park
# 25                      Greens Vegetarian Restaurant  Alexandra Park
# 26                     Nikolaou Restaurant Equipment  Alexandra Park
# 27                   Full Moon Vegetarian Restaurant  Alexandra Park
# 28               Pat's Homestyle Jamaican Restaurant  Alexandra Park
# 29                                   Barn Restaurant  Alexandra Park
# ..                                               ...             ...
# 726                                 Bloom Restaurant        Wychwood
# 727                                 Pukka Restaurant        Wychwood
# 728                           Garden Deli Restaurant      York Mills
# 729   Sassafraz | Cafe | Restaurant | Private Events       Yorkville
# 730                            ONE Restaurant/Lounge       Yorkville
# 731                       Matisse Restaurant And Bar       Yorkville
# 732                                  True Restaurant       Yorkville
# 733                                Sorrel Restaurant       Yorkville
# 734                       Yamato Japanese Restaurant       Yorkville
# 735                              Brothers Restaurant       Yorkville
# 736                             Kathmandu Restaurant       Yorkville
# 737                      Regal 16 Chinese Restaurant       Yorkville
# 738                            Waterfalls restaurant       Yorkville
# 739                       Shogun Japanese Restaurant       Yorkville
# 740                          Dynasty Chinese Cuisine       Yorkville
# 741                               Scaccia Restaurant       Yorkville
# 742                                   OJA Restaurant       Yorkville
# 743                           Amber Restaurant & Bar       Yorkville
# 744                                   Zin Restaurant       Yorkville
# 745                          China Garden Restaurant       Yorkville
# 746                        Blu Ristorante and Lounge       Yorkville
# 747                                           Subway       Yorkville
# 748                                           Subway       Yorkville
# 749                                     Sunset Grill       Yorkville
# 750                                      Hemingway's       Yorkville
# 751                                           Subway       Yorkville
# 752           Toronto Marriott Bloor Yorkville Hotel       Yorkville
# 753                                    King's Palace       Yorkville
# 754                                           Subway       Yorkville
# 755                                    Tokyo Kitchen       Yorkville
#
#                         categories        lat        lng  \
# 0               Chinese Restaurant  43.785937 -79.276031
# 1               Chinese Restaurant  43.786210 -79.275701
# 2                Korean Restaurant  43.786468 -79.275693
# 3               Chinese Restaurant  43.787078 -79.275454
# 4               Chinese Restaurant  43.784898 -79.278272
# 5             Cantonese Restaurant  43.785087 -79.277843
# 6               Chinese Restaurant  43.785164 -79.279433
# 7             Cantonese Restaurant  43.784725 -79.277556
# 8               Chinese Restaurant  43.784513 -79.277735
# 9                 Asian Restaurant  43.785822 -79.276714
# 10          Peking Duck Restaurant  43.786179 -79.275756
# 11                      Restaurant  43.786933 -79.274230
# 12              Chinese Restaurant  43.787066 -79.274782
# 13                Asian Restaurant  43.786896 -79.273973
# 14         South Indian Restaurant  43.781806 -79.276560
# 15            Cantonese Restaurant  43.785700 -79.284316
# 16            Hong Kong Restaurant  43.786779 -79.277179
# 17            Hong Kong Restaurant  43.787108 -79.275931
# 18                     Pizza Place  43.601280 -79.545028
# 19                  Breakfast Spot  43.652803 -79.399958
# 20                             Bar  43.647289 -79.403493
# 21              Dim Sum Restaurant  43.652783 -79.398174
# 22                    Noodle House  43.652278 -79.398039
# 23               Korean Restaurant  43.654307 -79.399277
# 24              Chinese Restaurant  43.652488 -79.397501
# 25   Vegetarian / Vegan Restaurant  43.652034 -79.402382
# 26            Kitchen Supply Store  43.647378 -79.403165
# 27                            None  43.652131 -79.402520
# 28            Caribbean Restaurant  43.647386 -79.403210
# 29                           Diner  43.647233 -79.404508
# ..                             ...        ...        ...
# 726                           None  43.683081 -79.420353
# 727              Indian Restaurant  43.681055 -79.429187
# 728                          Diner  43.746296 -79.406698
# 729                    Event Space  43.670342 -79.391041
# 730        New American Restaurant  43.670809 -79.393272
# 731                     Restaurant  43.670574 -79.384856
# 732             Italian Restaurant  43.671073 -79.390808
# 733        New American Restaurant  43.671055 -79.391458
# 734            Japanese Restaurant  43.670683 -79.391056
# 735                     Restaurant  43.670421 -79.389793
# 736              Indian Restaurant  43.671023 -79.387957
# 737             Chinese Restaurant  43.670450 -79.392822
# 738              Indian Restaurant  43.670130 -79.392800
# 739            Japanese Restaurant  43.669934 -79.393227
# 740             Dim Sum Restaurant  43.671141 -79.390827
# 741             Italian Restaurant  43.668794 -79.388296
# 742               Sushi Restaurant  43.668943 -79.386241
# 743                   Cocktail Bar  43.670407 -79.392853
# 744             Chinese Restaurant  43.672401 -79.395712
# 745             Chinese Restaurant  43.668383 -79.395363
# 746             Italian Restaurant  43.671685 -79.388614
# 747                 Sandwich Place  43.671656 -79.387610
# 748                 Sandwich Place  43.667527 -79.388919
# 749                 Breakfast Spot  43.670809 -79.384200
# 750                     Restaurant  43.670081 -79.392744
# 751                 Sandwich Place  43.674438 -79.388703
# 752                          Hotel  43.670009 -79.393281
# 753              Indian Restaurant  43.672214 -79.385843
# 754                 Sandwich Place  43.668423 -79.395421
# 755            Japanese Restaurant  43.668783 -79.385153
#
#                            id  frequency
# 0    4be303c52fc7d13ae879083a         18
# 1    4baa46def964a520485a3ae3         18
# 2    4d2f8a98789a8cfa6b0826c6         18
# 3    53dbb77e498e6dfadda043fa         18
# 4    4f3852b7e4b0ea2d7edc00ca         18
# 5    5647afde498e42030b40c86d         18
# 6    54838447498e2f5b90530813         18
# 7    53489594498e2802cb19ddca         18
# 8    5d80fe5ba86ac4000795406a         18
# 9    4d2bbbf3888af04db4abe2af         18
# 10   564fbc10498e317227340ab1         18
# 11   4d2b495d6e27a143be653624         18
# 12   4b2f7fb2f964a520d3eb24e3         18
# 13   4e13471a8877ac23b67131df         18
# 14   4c54a130f5f3d13ab41070fa         18
# 15   550225c3498e887caf37f7be         18
# 16   51d84f68498e20fcf16c13d9         18
# 17   4bb74fea1344b7136f8e9e04         18
# 18   4c47927c1ddec928fbec9d32          1
# 19   4bce1ec0cc8cd13a9ac8c3cf         25
# 20   4c47d78c1ddec92817ca9e32         25
# 21   4b072e9df964a52009f922e3         25
# 22   4b266f05f964a520657b24e3         25
# 23   4ba2d00cf964a5203e1b38e3         25
# 24   5c33c7cd8194fc002c66f72e         25
# 25   4cb79089dd41a35d6a2fd4a0         25
# 26   4cdee51278ddf04d0a7c9d98         25
# 27   4b8171a1f964a5205da630e3         25
# 28   4b6e3f5ef964a52021b42ce3         25
# 29   4ba64368f964a520684039e3         25
# ..                        ...        ...
# 726  5561802a498e00cae8804d5e          3
# 727  52418b0b7e48222eea81d2d2          3
# 728  4d5ab9013281b1f7fe01c92f          1
# 729  4ad4c05cf964a520cef520e3         27
# 730  4b02a076f964a520234922e3         27
# 731  4b4d3b51f964a520e4ce26e3         27
# 732  4addf19ef964a520916621e3         27
# 733  4d35c67e97fa5941b5ba603e         27
# 734  4ad4c05ff964a5203af720e3         27
# 735  580aea74d67c230d453b04aa         27
# 736  5605d124498e0f46d602ee3a         27
# 737  4d1a8e03dd363704e88d5c1a         27
# 738  4e7e17295503d17f912287fc         27
# 739  4ad4c060f964a52062f720e3         27
# 740  4d0d035a903d37042c51c155         27
# 741  4adcc289f964a520812f21e3         27
# 742  4adc9ad8f964a520ce2d21e3         27
# 743  4ad4c05df964a52042f620e3         27
# 744  4b5e3cc6f964a5207b8529e3         27
# 745  4b880a37f964a5200cdb31e3         27
# 746  4b737d37f964a520f6b02de3         27
# 747  4c0d6173e60fb713bf502122         27
# 748  4c0e3ec52466a59312b07821         27
# 749  4d260aa45cc1a093cd6b98be         27
# 750  4ad4c05df964a52054f620e3         27
# 751  4bbf6dfc30c99c74fe2e5511         27
# 752  4ae1cb55f964a520758721e3         27
# 753  4afa45ddf964a5209b1722e3         27
# 754  4c17c9f02cddb7134f0b831e         27
# 755  4ae787b9f964a52020ac21e3         27
#
# [756 rows x 7 columns]

# %% [markdown]
# <h3> Combine 'all_venues' with 'compiled_df' to obtain the final dataframe with all the required parameters -

# %%
final_df = compiled_df.iloc[:, :]

# create a mask for names for which we actually have any restaurant data
mask = [True if name in list(all_venues['city']) else False for name in final_df.index.values]
final_df = final_df[mask]

final_df['frequency'] = [all_venues[all_venues['city'] == name].shape[0] for name in final_df.index.values]
final_df['potential'] = final_df['Density (people/km2)'] * final_df['Average Income'] / final_df['frequency']

# only keep the required columns
columns = ['Population', 'Land area (km2)', 'Density (people/km2)', 'Average Income', 'frequency', 'potential', 'latitude', 'longitude']
final_df = final_df[columns]

# remove rogue locations ;P
final_df = final_df[final_df['latitude'] >= 43]
final_df = final_df[final_df['latitude'] <= 44]
final_df = final_df[final_df['longitude'] >= -80]
final_df = final_df[final_df['longitude'] <= -79]

# final_df.reset_index(inplace=True)
# final_df.drop(columns='index', inplace=True)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
final_df
# Out:
#                                     Population  Land area (km2)  \
# Name
# Agincourt                                44577            12.45
# Alderwood                                11656             4.94
# Alexandra Park                            4355             0.32
# Bay Street Corridor                       4787             0.11
# Bloor West Village                        5175             0.74
# Bracondale Hill                           5343             0.62
# Brockton                                  9039             1.10
# Cabbagetown                              11120             1.40
# Carleton Village                          6544             0.74
# Chaplin Estates                           4906             0.93
# Christie Pits                             5124             0.64
# Church and Wellesley                     13397             0.55
# Clairlea                                 11104             3.58
# Cliffcrest                               14531             7.01
# Corktown                                  4484             0.67
# Crescent Town                             8157             0.40
# Davenport                                 8781             0.99
# Davisville                               23727             3.14
# Deer Park                                15165             1.46
# Discovery District                        7262             0.66
# Distillery District/West Don Lands        6378             1.33
# Don Mills                                21372             8.99
# Don Valley Village                       29740             5.16
# Dorset Park                              14189             4.26
# Dovercourt Park                           8497             0.87
# Downsview                                36613            16.13
# Dufferin Grove                            9875             0.99
# Earlscourt                               17240             2.24
# Eglinton East                            22387             3.23
# Eringate                                  8008             2.44
# ...                                        ...              ...
# Runnymede                                 4382             0.85
# Scarborough Junction                     25780             7.41
# Scarborough City Centre                  16403             2.58
# Scarborough Village                      12796             2.03
# Seaton Village                            5259             0.62
# Silverthorn                              17757             3.52
# St. James Town                           14666             0.23
# Summerhill                                5100             0.65
# Swansea                                  11133             3.76
# The Annex                                15602             1.47
# The Beaches                              20416             3.57
# The Danforth                              7849             0.87
# The Junction                             11391             2.36
# The Kingsway                              8780             2.58
# The Queensway                             6207             2.62
# Thistletown                              16790             3.97
# Thorncliffe Park                         17949             3.09
# Trinity–Bellwoods                         8687             0.92
# Upper Beaches                            19830             2.92
# Victoria Village                         17047             4.72
# Wallace Emerson                          10338             0.88
# West Hill                                25632             9.58
# Weston                                   16476             2.51
# Wexford                                  17844             7.97
# Willowdale                               43144             7.68
# Wilson Heights                           13732             4.14
# Woburn                                   48507            13.34
# Wychwood                                  4182             0.68
# York Mills                               17564             7.29
# Yorkville                                 6045             0.56
#
#                                     Density (people/km2)  Average Income  \
# Name
# Agincourt                                           3580           25750
# Alderwood                                           2360           35239
# Alexandra Park                                     13609           19687
# Bay Street Corridor                                43518           40598
# Bloor West Village                                  6993           55578
# Bracondale Hill                                     8618           41605
# Brockton                                            8217           27260
# Cabbagetown                                         7943           50398
# Carleton Village                                    8843           23301
# Chaplin Estates                                     5275           81288
# Christie Pits                                       8006           30556
# Church and Wellesley                               24358           37653
# Clairlea                                            3102           33392
# Cliffcrest                                          2073           38182
# Corktown                                            6693           54681
# Crescent Town                                      20393           23021
# Davenport                                           8870           28335
# Davisville                                          7556           55735
# Deer Park                                          10387           80704
# Discovery District                                  6998           41998
# Distillery District/West Don Lands                  4795           40617
# Don Mills                                           2377           47515
# Don Valley Village                                  5764           30442
# Dorset Park                                         3331           26525
# Dovercourt Park                                     9767           28311
# Downsview                                           2270           26751
# Dufferin Grove                                      9975           27961
# Earlscourt                                          7696           26672
# Eglinton East                                       6931           25307
# Eringate                                            3282           34789
# ...                                                  ...             ...
# Runnymede                                           5155           42635
# Scarborough Junction                                3479           25405
# Scarborough City Centre                             6358           26756
# Scarborough Village                                 6303           24413
# Seaton Village                                      8482           41506
# Silverthorn                                         5045           26291
# St. James Town                                     63765           22341
# Summerhill                                          7846           88937
# Swansea                                             2961           58681
# The Annex                                          10614           63636
# The Beaches                                         5719           67536
# The Danforth                                        9022           44979
# The Junction                                        4827           34906
# The Kingsway                                        3403          110944
# The Queensway                                       2369           38944
# Thistletown                                         4229           28955
# Thorncliffe Park                                    5809           25340
# Trinity–Bellwoods                                   9442           31106
# Upper Beaches                                       6791           44346
# Victoria Village                                    3612           29657
# Wallace Emerson                                    11748           25029
# West Hill                                           2676           27936
# Weston                                              6564           27446
# Wexford                                             2239           28556
# Willowdale                                          5618           39895
# Wilson Heights                                      3317           37978
# Woburn                                              3636           26190
# Wychwood                                            6150           53613
# York Mills                                          2409           92099
# Yorkville                                          10795          105239
#
#                                     frequency     potential   latitude  \
# Name
# Agincourt                                  18  5.121389e+06  43.785353
# Alderwood                                   1  8.316404e+07  43.601717
# Alexandra Park                             25  1.071682e+07  43.650787
# Bay Street Corridor                        29  6.092220e+07  43.667342
# Bloor West Village                          5  7.773139e+07  43.649318
# Bracondale Hill                             1  3.585519e+08  43.676195
# Brockton                                    1  2.239954e+08  43.650917
# Cabbagetown                                 8  5.003891e+07  43.664473
# Carleton Village                            3  6.868358e+07  43.670701
# Chaplin Estates                             8  5.359928e+07  43.702598
# Christie Pits                              11  2.223921e+07  43.667139
# Church and Wellesley                       21  4.367389e+07  43.665524
# Clairlea                                    3  3.452733e+07  43.708823
# Cliffcrest                                  1  7.915129e+07  43.721836
# Corktown                                    2  1.829900e+08  43.657370
# Crescent Town                               2  2.347336e+08  43.695403
# Davenport                                   3  8.377715e+07  43.671545
# Davisville                                  3  1.403779e+08  43.697936
# Deer Park                                   7  1.197532e+08  43.688090
# Discovery District                         30  9.796733e+06  43.657556
# Distillery District/West Don Lands          3  6.491950e+07  43.650295
# Don Mills                                   1  1.129432e+08  43.775347
# Don Valley Village                          9  1.949641e+07  43.792673
# Dorset Park                                 2  4.417739e+07  43.752847
# Dovercourt Park                             4  6.912838e+07  43.665223
# Downsview                                   1  6.072477e+07  43.749299
# Dufferin Grove                              7  3.984442e+07  43.653632
# Earlscourt                                  2  1.026339e+08  43.676277
# Eglinton East                               4  4.385070e+07  43.739465
# Eringate                                    1  1.141775e+08  43.662273
# ...                                       ...           ...        ...
# Runnymede                                   6  3.663057e+07  43.651703
# Scarborough Junction                        2  4.419200e+07  43.716049
# Scarborough City Centre                     1  1.701146e+08  43.773077
# Scarborough Village                         2  7.693757e+07  43.743742
# Seaton Village                              7  5.029341e+07  43.669276
# Silverthorn                                 2  6.631905e+07  43.682123
# St. James Town                              7  2.035106e+08  43.669403
# Summerhill                                  6  1.163000e+08  43.681678
# Swansea                                     1  1.737544e+08  43.644940
# The Annex                                   4  1.688581e+08  43.670338
# The Beaches                                 4  9.655960e+07  43.671024
# The Danforth                                2  2.029003e+08  43.686433
# The Junction                                1  1.684913e+08  43.665478
# The Kingsway                                1  3.775424e+08  43.647381
# The Queensway                               2  4.612917e+07  43.623618
# Thistletown                                 6  2.040845e+07  43.737266
# Thorncliffe Park                            6  2.453334e+07  43.704553
# Trinity–Bellwoods                           3  9.790095e+07  43.647565
# Upper Beaches                               2  1.505768e+08  43.678488
# Victoria Village                            2  5.356054e+07  43.732658
# Wallace Emerson                             1  2.940407e+08  43.666733
# West Hill                                   4  1.868918e+07  43.768914
# Weston                                      6  3.002592e+07  43.700161
# Wexford                                     6  1.065615e+07  43.745377
# Willowdale                                  7  3.201859e+07  43.761510
# Wilson Heights                              4  3.149326e+07  43.740519
# Woburn                                      3  3.174228e+07  43.759824
# Wychwood                                    3  1.099066e+08  43.682171
# York Mills                                  1  2.218665e+08  43.744039
# Yorkville                                  27  4.207611e+07  43.671386
#
#                                     longitude
# Name
# Agincourt                          -79.278549
# Alderwood                          -79.545232
# Alexandra Park                     -79.404318
# Bay Street Corridor                -79.388457
# Bloor West Village                 -79.484436
# Bracondale Hill                    -79.428016
# Brockton                           -79.440022
# Cabbagetown                        -79.366986
# Carleton Village                   -79.453299
# Chaplin Estates                    -79.403270
# Christie Pits                      -79.422766
# Church and Wellesley               -79.383801
# Clairlea                           -79.295986
# Cliffcrest                         -79.236214
# Corktown                           -79.356513
# Crescent Town                      -79.293099
# Davenport                          -79.448322
# Davisville                         -79.397291
# Deer Park                          -79.394093
# Discovery District                 -79.389480
# Distillery District/West Don Lands -79.359540
# Don Mills                          -79.345944
# Don Valley Village                 -79.354722
# Dorset Park                        -79.282067
# Dovercourt Park                    -79.433537
# Downsview                          -79.462248
# Dufferin Grove                     -79.426439
# Earlscourt                         -79.450572
# Eglinton East                      -79.232100
# Eringate                           -79.576516
# ...                                       ...
# Runnymede                          -79.475998
# Scarborough Junction               -79.260703
# Scarborough City Centre            -79.257774
# Scarborough Village                -79.211632
# Seaton Village                     -79.415960
# Silverthorn                        -79.471572
# St. James Town                     -79.372704
# Summerhill                         -79.390504
# Swansea                            -79.478313
# The Annex                          -79.407117
# The Beaches                        -79.296712
# The Danforth                       -79.300355
# The Junction                       -79.470352
# The Kingsway                       -79.511333
# The Queensway                      -79.514764
# Thistletown                        -79.565317
# Thorncliffe Park                   -79.345407
# Trinity–Bellwoods                  -79.413881
# Upper Beaches                      -79.310819
# Victoria Village                   -79.311189
# Wallace Emerson                    -79.446478
# West Hill                          -79.187291
# Weston                             -79.516247
# Wexford                            -79.294715
# Willowdale                         -79.410923
# Wilson Heights                     -79.440017
# Woburn                             -79.225291
# Wychwood                           -79.423113
# York Mills                         -79.406657
# Yorkville                          -79.390168
#
# [108 rows x 8 columns]

# %%
final_df.sort_values(by='potential', ascending=False)
# Out:
#                                       Population  Land area (km2)  \
# Name
# High Park North                            22746             2.18
# Old Mill/Baby Point                         4010             1.07
# The Kingsway                                8780             2.58
# Bracondale Hill                             5343             0.62
# Humewood–Cedarvale                         27515             3.19
# Wallace Emerson                            10338             0.88
# Forest Hill                                24056             4.35
# Crescent Town                               8157             0.40
# Lawrence Manor                             13750             2.14
# Brockton                                    9039             1.10
# York Mills                                 17564             7.29
# St. James Town                             14666             0.23
# The Danforth                                7849             0.87
# Parkwoods                                  26533             4.96
# Corktown                                    4484             0.67
# Swansea                                    11133             3.76
# Scarborough City Centre                    16403             2.58
# The Annex                                  15602             1.47
# The Junction                               11391             2.36
# Regent Park/Trefann Court                  10387             0.64
# Upper Beaches                              19830             2.92
# Governor's Bridge/Bennington Heights        2112             1.87
# Davisville                                 23727             3.14
# Kingsview Village                          16254             4.05
# Parkway Forest                              8498             1.71
# Deer Park                                  15165             1.46
# Summerhill                                  5100             0.65
# Eringate                                    8008             2.44
# Don Mills                                  21372             8.99
# Wychwood                                    4182             0.68
# ...                                          ...              ...
# Runnymede                                   4382             0.85
# Fairbank                                   34121             4.42
# Clairlea                                   11104             3.58
# Willowdale                                 43144             7.68
# Woburn                                     48507            13.34
# Wilson Heights                             13732             4.14
# Weston                                     16476             2.51
# Flemingdon Park                            21287             2.43
# Thorncliffe Park                           17949             3.09
# Christie Pits                               5124             0.64
# Humber Summit                              12766             7.89
# Harbord Village                             5906             0.64
# Thistletown                                16790             3.97
# Don Valley Village                         29740             5.16
# West Hill                                  25632             9.58
# Garden District                             8240             0.52
# Fort York/Liberty Village                   3821             2.13
# Newtonbrook                                36046             8.77
# Lawrence Heights                            3769             3.20
# Alexandra Park                              4355             0.32
# Wexford                                    17844             7.97
# Fashion District                            4642             0.98
# Discovery District                          7262             0.66
# Grange Park                                 9007             0.84
# Milliken                                   26272             7.19
# Humberwood                                  7319            17.40
# Kensington Market                           3740             0.36
# Agincourt                                  44577            12.45
# Port Lands                                   571             6.10
# Financial District                           548             0.47
#
#                                       Density (people/km2)  Average Income  \
# Name
# High Park North                                      10434           46437
# Old Mill/Baby Point                                   3748          110372
# The Kingsway                                          3403          110944
# Bracondale Hill                                       8618           41605
# Humewood–Cedarvale                                    8624           40404
# Wallace Emerson                                      11748           25029
# Forest Hill                                           5530          101631
# Crescent Town                                        20393           23021
# Lawrence Manor                                        6425           36361
# Brockton                                              8217           27260
# York Mills                                            2409           92099
# St. James Town                                       63765           22341
# The Danforth                                          9022           44979
# Parkwoods                                             5349           34811
# Corktown                                              6693           54681
# Swansea                                               2961           58681
# Scarborough City Centre                               6358           26756
# The Annex                                            10614           63636
# The Junction                                          4827           34906
# Regent Park/Trefann Court                            16230           19521
# Upper Beaches                                         6791           44346
# Governor's Bridge/Bennington Heights                  1129          129904
# Davisville                                            7556           55735
# Kingsview Village                                     4013           32004
# Parkway Forest                                        4970           24333
# Deer Park                                            10387           80704
# Summerhill                                            7846           88937
# Eringate                                              3282           34789
# Don Mills                                             2377           47515
# Wychwood                                              6150           53613
# ...                                                    ...             ...
# Runnymede                                             5155           42635
# Fairbank                                              7720           28403
# Clairlea                                              3102           33392
# Willowdale                                            5618           39895
# Woburn                                                3636           26190
# Wilson Heights                                        3317           37978
# Weston                                                6564           27446
# Flemingdon Park                                       8760           23471
# Thorncliffe Park                                      5809           25340
# Christie Pits                                         8006           30556
# Humber Summit                                         1618           26117
# Harbord Village                                       9228           45792
# Thistletown                                           4229           28955
# Don Valley Village                                    5764           30442
# West Hill                                             2676           27936
# Garden District                                      15846           37614
# Fort York/Liberty Village                             1794           46086
# Newtonbrook                                           4110           33428
# Lawrence Heights                                      1178           29867
# Alexandra Park                                       13609           19687
# Wexford                                               2239           28556
# Fashion District                                      4737           63282
# Discovery District                                    6998           41998
# Grange Park                                          10793           35277
# Milliken                                              3654           25243
# Humberwood                                             421           29576
# Kensington Market                                    10389           23335
# Agincourt                                             3580           25750
# Port Lands                                              94           36243
# Financial District                                    1166           63952
#
#                                       frequency     potential   latitude  \
# Name
# High Park North                               1  4.845237e+08  43.657383
# Old Mill/Baby Point                           1  4.136743e+08  43.649826
# The Kingsway                                  1  3.775424e+08  43.647381
# Bracondale Hill                               1  3.585519e+08  43.676195
# Humewood–Cedarvale                            1  3.484441e+08  43.690248
# Wallace Emerson                               1  2.940407e+08  43.666733
# Forest Hill                                   2  2.810097e+08  43.693559
# Crescent Town                                 2  2.347336e+08  43.695403
# Lawrence Manor                                1  2.336194e+08  43.722079
# Brockton                                      1  2.239954e+08  43.650917
# York Mills                                    1  2.218665e+08  43.744039
# St. James Town                                7  2.035106e+08  43.669403
# The Danforth                                  2  2.029003e+08  43.686433
# Parkwoods                                     1  1.862040e+08  43.758800
# Corktown                                      2  1.829900e+08  43.657370
# Swansea                                       1  1.737544e+08  43.644940
# Scarborough City Centre                       1  1.701146e+08  43.773077
# The Annex                                     4  1.688581e+08  43.670338
# The Junction                                  1  1.684913e+08  43.665478
# Regent Park/Trefann Court                     2  1.584129e+08  43.660706
# Upper Beaches                                 2  1.505768e+08  43.678488
# Governor's Bridge/Bennington Heights          1  1.466616e+08  43.689423
# Davisville                                    3  1.403779e+08  43.697936
# Kingsview Village                             1  1.284321e+08  43.699539
# Parkway Forest                                1  1.209350e+08  43.771660
# Deer Park                                     7  1.197532e+08  43.688090
# Summerhill                                    6  1.163000e+08  43.681678
# Eringate                                      1  1.141775e+08  43.662273
# Don Mills                                     1  1.129432e+08  43.775347
# Wychwood                                      3  1.099066e+08  43.682171
# ...                                         ...           ...        ...
# Runnymede                                     6  3.663057e+07  43.651703
# Fairbank                                      6  3.654519e+07  43.695689
# Clairlea                                      3  3.452733e+07  43.708823
# Willowdale                                    7  3.201859e+07  43.761510
# Woburn                                        3  3.174228e+07  43.759824
# Wilson Heights                                4  3.149326e+07  43.740519
# Weston                                        6  3.002592e+07  43.700161
# Flemingdon Park                               7  2.937228e+07  43.718432
# Thorncliffe Park                              6  2.453334e+07  43.704553
# Christie Pits                                11  2.223921e+07  43.667139
# Humber Summit                                 2  2.112865e+07  43.760078
# Harbord Village                              20  2.112843e+07  43.661522
# Thistletown                                   6  2.040845e+07  43.737266
# Don Valley Village                            9  1.949641e+07  43.792673
# West Hill                                     4  1.868918e+07  43.768914
# Garden District                              36  1.655643e+07  43.656500
# Fort York/Liberty Village                     5  1.653566e+07  43.638992
# Newtonbrook                                  10  1.373891e+07  43.793886
# Lawrence Heights                              3  1.172778e+07  43.722778
# Alexandra Park                               25  1.071682e+07  43.650787
# Wexford                                       6  1.065615e+07  43.745377
# Fashion District                             29  1.033679e+07  43.645456
# Discovery District                           30  9.796733e+06  43.657556
# Grange Park                                  48  7.932180e+06  43.652197
# Milliken                                     13  7.095225e+06  43.823174
# Humberwood                                    2  6.225748e+06  43.722525
# Kensington Market                            41  5.912861e+06  43.655214
# Agincourt                                    18  5.121389e+06  43.785353
# Port Lands                                    1  3.406842e+06  43.643065
# Financial District                           37  2.015352e+06  43.648664
#
#                                       longitude
# Name
# High Park North                      -79.470961
# Old Mill/Baby Point                  -79.494334
# The Kingsway                         -79.511333
# Bracondale Hill                      -79.428016
# Humewood–Cedarvale                   -79.422097
# Wallace Emerson                      -79.446478
# Forest Hill                          -79.413902
# Crescent Town                        -79.293099
# Lawrence Manor                       -79.437507
# Brockton                             -79.440022
# York Mills                           -79.406657
# St. James Town                       -79.372704
# The Danforth                         -79.300355
# Parkwoods                            -79.320197
# Corktown                             -79.356513
# Swansea                              -79.478313
# Scarborough City Centre              -79.257774
# The Annex                            -79.407117
# The Junction                         -79.470352
# Regent Park/Trefann Court            -79.360457
# Upper Beaches                        -79.310819
# Governor's Bridge/Bennington Heights -79.369426
# Davisville                           -79.397291
# Kingsview Village                    -79.556346
# Parkway Forest                       -79.342663
# Deer Park                            -79.394093
# Summerhill                           -79.390504
# Eringate                             -79.576516
# Don Mills                            -79.345944
# Wychwood                             -79.423113
# ...                                         ...
# Runnymede                            -79.475998
# Fairbank                             -79.450310
# Clairlea                             -79.295986
# Willowdale                           -79.410923
# Woburn                               -79.225291
# Wilson Heights                       -79.440017
# Weston                               -79.516247
# Flemingdon Park                      -79.333204
# Thorncliffe Park                     -79.345407
# Christie Pits                        -79.422766
# Humber Summit                        -79.571760
# Harbord Village                      -79.409745
# Thistletown                          -79.565317
# Don Valley Village                   -79.354722
# West Hill                            -79.187291
# Garden District                      -79.377114
# Fort York/Liberty Village            -79.403445
# Newtonbrook                          -79.425679
# Lawrence Heights                     -79.450933
# Alexandra Park                       -79.404318
# Wexford                              -79.294715
# Fashion District                     -79.394994
# Discovery District                   -79.389480
# Grange Park                          -79.392319
# Milliken                             -79.301763
# Humberwood                           -79.546024
# Kensington Market                    -79.402260
# Agincourt                            -79.278549
# Port Lands                           -79.350601
# Financial District                   -79.381540
#
# [108 rows x 8 columns]

# %% [markdown]
# High Park North seems to be the place with the most potential!

# %% [markdown]
# <h3> Map this dataframe with the radius of each bubble being proportional to its potential -

# %%
map_toronto = folium.Map(location=[latitude+0.05, longitude], zoom_start=11.5)    # center point of the map

for lat, lng, label, pot in zip(final_df['latitude'], final_df['longitude'], final_df.index.values, final_df['potential']):
    label = folium.Popup(label, parse_html=True)
    folium.Circle(    # attributes of each bubble in the map
        [lat, lng],
        radius=pot*2/(10**6),
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# One apparent shortcoming of this model is the fact that 'potential' is very sensitive towards neighborhoods with only 1 or 2 documented restaurants, since even if only one or two more restaurants are added in these places, the potential will get halved. This makes the model very vulnerable if there is even one restaurant undocumented in these places.

# %% [markdown]
# So, to counter this issue and add a scent of robustness to the model, let's consider only those neighborhoods which have more than 10 documented restaurants. This will make 'potential' significantly less sensitive if more restaurants are documented at a later stage.

# %% [markdown]
# <h3> Remove places with less than 10 restaurants -

# %%
sliced_df = final_df[final_df['frequency'] >= 10]
sliced_df
# Out:
#                           Population  Land area (km2)  Density (people/km2)  \
# Name
# Agincourt                      44577            12.45                  3580
# Alexandra Park                  4355             0.32                 13609
# Bay Street Corridor             4787             0.11                 43518
# Christie Pits                   5124             0.64                  8006
# Church and Wellesley           13397             0.55                 24358
# Discovery District              7262             0.66                  6998
# Fashion District                4642             0.98                  4737
# Financial District               548             0.47                  1166
# Garden District                 8240             0.52                 15846
# Grange Park                     9007             0.84                 10793
# Harbord Village                 5906             0.64                  9228
# Harbourfront / CityPlace       14368             1.87                  9228
# Kensington Market               3740             0.36                 10389
# Milliken                       26272             7.19                  3654
# Newtonbrook                    36046             8.77                  4110
# Niagara                         6524             0.55                 11862
# Yorkville                       6045             0.56                 10795
#
#                           Average Income  frequency     potential   latitude  \
# Name
# Agincourt                          25750         18  5.121389e+06  43.785353
# Alexandra Park                     19687         25  1.071682e+07  43.650787
# Bay Street Corridor                40598         29  6.092220e+07  43.667342
# Christie Pits                      30556         11  2.223921e+07  43.667139
# Church and Wellesley               37653         21  4.367389e+07  43.665524
# Discovery District                 41998         30  9.796733e+06  43.657556
# Fashion District                   63282         29  1.033679e+07  43.645456
# Financial District                 63952         37  2.015352e+06  43.648664
# Garden District                    37614         36  1.655643e+07  43.656500
# Grange Park                        35277         48  7.932180e+06  43.652197
# Harbord Village                    45792         20  2.112843e+07  43.661522
# Harbourfront / CityPlace           69232         14  4.563378e+07  43.640080
# Kensington Market                  23335         41  5.912861e+06  43.655214
# Milliken                           25243         13  7.095225e+06  43.823174
# Newtonbrook                        33428         10  1.373891e+07  43.793886
# Niagara                            44611         11  4.810688e+07  43.644075
# Yorkville                         105239         27  4.207611e+07  43.671386
#
#                           longitude
# Name
# Agincourt                -79.278549
# Alexandra Park           -79.404318
# Bay Street Corridor      -79.388457
# Christie Pits            -79.422766
# Church and Wellesley     -79.383801
# Discovery District       -79.389480
# Fashion District         -79.394994
# Financial District       -79.381540
# Garden District          -79.377114
# Grange Park              -79.392319
# Harbord Village          -79.409745
# Harbourfront / CityPlace -79.380150
# Kensington Market        -79.402260
# Milliken                 -79.301763
# Newtonbrook              -79.425679
# Niagara                  -79.408698
# Yorkville                -79.390168

# %%
print(sliced_df['frequency'].sum())
sliced_df.sort_values(by='potential', ascending=False)
# Out:
# 420
#                           Population  Land area (km2)  Density (people/km2)  \
# Name
# Bay Street Corridor             4787             0.11                 43518
# Niagara                         6524             0.55                 11862
# Harbourfront / CityPlace       14368             1.87                  9228
# Church and Wellesley           13397             0.55                 24358
# Yorkville                       6045             0.56                 10795
# Christie Pits                   5124             0.64                  8006
# Harbord Village                 5906             0.64                  9228
# Garden District                 8240             0.52                 15846
# Newtonbrook                    36046             8.77                  4110
# Alexandra Park                  4355             0.32                 13609
# Fashion District                4642             0.98                  4737
# Discovery District              7262             0.66                  6998
# Grange Park                     9007             0.84                 10793
# Milliken                       26272             7.19                  3654
# Kensington Market               3740             0.36                 10389
# Agincourt                      44577            12.45                  3580
# Financial District               548             0.47                  1166
#
#                           Average Income  frequency     potential   latitude  \
# Name
# Bay Street Corridor                40598         29  6.092220e+07  43.667342
# Niagara                            44611         11  4.810688e+07  43.644075
# Harbourfront / CityPlace           69232         14  4.563378e+07  43.640080
# Church and Wellesley               37653         21  4.367389e+07  43.665524
# Yorkville                         105239         27  4.207611e+07  43.671386
# Christie Pits                      30556         11  2.223921e+07  43.667139
# Harbord Village                    45792         20  2.112843e+07  43.661522
# Garden District                    37614         36  1.655643e+07  43.656500
# Newtonbrook                        33428         10  1.373891e+07  43.793886
# Alexandra Park                     19687         25  1.071682e+07  43.650787
# Fashion District                   63282         29  1.033679e+07  43.645456
# Discovery District                 41998         30  9.796733e+06  43.657556
# Grange Park                        35277         48  7.932180e+06  43.652197
# Milliken                           25243         13  7.095225e+06  43.823174
# Kensington Market                  23335         41  5.912861e+06  43.655214
# Agincourt                          25750         18  5.121389e+06  43.785353
# Financial District                 63952         37  2.015352e+06  43.648664
#
#                           longitude
# Name
# Bay Street Corridor      -79.388457
# Niagara                  -79.408698
# Harbourfront / CityPlace -79.380150
# Church and Wellesley     -79.383801
# Yorkville                -79.390168
# Christie Pits            -79.422766
# Harbord Village          -79.409745
# Garden District          -79.377114
# Newtonbrook              -79.425679
# Alexandra Park           -79.404318
# Fashion District         -79.394994
# Discovery District       -79.389480
# Grange Park              -79.392319
# Milliken                 -79.301763
# Kensington Market        -79.402260
# Agincourt                -79.278549
# Financial District       -79.381540

# %% [markdown]
# Here again, land area seems to dominate 'potential'. A way around could be to scale all parameters between 1 and 2 and then recalculate 'potential'. That will give each parameter equal opportunity to affect the final potential.

# %% [markdown]
# <h3> Re-scale all 'potential' affecting parameters -

# %%
scaled_df = sliced_df.iloc[:, :]

# We want (1 / landArea(km2)) to fall between 1 and 2, where 1 means highest area and 2 means lowest area
scaled_df['Land area (km2) inv'] = 1 + ( 1/scaled_df['Land area (km2)'] - 1/scaled_df['Land area (km2)'].max() ) / ( 1/scaled_df['Land area (km2)'].min() - 1/scaled_df['Land area (km2)'].max() )

# We want (population) to fall between 1 and 2, where 1 means lowest population and 2 means highest population
scaled_df['Population pro'] = 1 + ( scaled_df['Population'] - scaled_df['Population'].min() ) / ( scaled_df['Population'].max() - scaled_df['Population'].min() )

# We want (averageIncome) to fall between 1 and 2, where 1 means lowest averageIncome and 2 means highest averageIncome
scaled_df['Average Income pro'] = 1 + ( scaled_df['Average Income'] - scaled_df['Average Income'].min() ) / ( scaled_df['Average Income'].max() - scaled_df['Average Income'].min() )

# We want (1 / frequency) to fall between 1 and 2, where 1 means highest frequency and 2 means lowest frequency
scaled_df['frequency inv'] = 1 + ( 1/scaled_df['frequency'] - 1/scaled_df['frequency'].max() ) / ( 1/scaled_df['frequency'].min() - 1/scaled_df['frequency'].max() )

# potential will simply be the product of all the above paramters!
scaled_df['potential'] = scaled_df['Land area (km2) inv'] * scaled_df['Population pro'] * scaled_df['Average Income pro'] * scaled_df['frequency inv']

scaled_df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                           Population  Land area (km2)  Density (people/km2)  \
# Name
# Agincourt                      44577            12.45                  3580
# Alexandra Park                  4355             0.32                 13609
# Bay Street Corridor             4787             0.11                 43518
# Christie Pits                   5124             0.64                  8006
# Church and Wellesley           13397             0.55                 24358
# Discovery District              7262             0.66                  6998
# Fashion District                4642             0.98                  4737
# Financial District               548             0.47                  1166
# Garden District                 8240             0.52                 15846
# Grange Park                     9007             0.84                 10793
# Harbord Village                 5906             0.64                  9228
# Harbourfront / CityPlace       14368             1.87                  9228
# Kensington Market               3740             0.36                 10389
# Milliken                       26272             7.19                  3654
# Newtonbrook                    36046             8.77                  4110
# Niagara                         6524             0.55                 11862
# Yorkville                       6045             0.56                 10795
#
#                           Average Income  frequency  potential   latitude  \
# Name
# Agincourt                          25750         18   3.081097  43.785353
# Alexandra Park                     19687         25   1.805503  43.650787
# Bay Street Corridor                40598         29   3.198895  43.667342
# Christie Pits                      30556         11   2.731306  43.667139
# Church and Wellesley               37653         21   2.495469  43.665524
# Discovery District                 41998         30   1.950390  43.657556
# Fashion District                   63282         29   2.136232  43.645456
# Financial District                 63952         37   2.007871  43.648664
# Garden District                    37614         36   1.861562  43.656500
# Grange Park                        35277         48   1.583003  43.652197
# Harbord Village                    45792         20   2.332847  43.661522
# Harbourfront / CityPlace           69232         14   3.572285  43.640080
# Kensington Market                  23335         41   1.518271  43.655214
# Milliken                           25243         13   2.901275  43.823174
# Newtonbrook                        33428         10   4.208387  43.793886
# Niagara                            44611         11   3.298033  43.644075
# Yorkville                         105239         27   3.223104  43.671386
#
#                           longitude  Land area (km2) inv  Population pro  \
# Name
# Agincourt                -79.278549             1.000000        2.000000
# Alexandra Park           -79.404318             1.337900        1.086466
# Bay Street Corridor      -79.388457             2.000000        1.096277
# Christie Pits            -79.422766             1.164493        1.103931
# Church and Wellesley     -79.383801             1.192869        1.291830
# Discovery District       -79.389480             1.159238        1.152490
# Fashion District         -79.394994             1.104331        1.092984
# Financial District       -79.381540             1.227215        1.000000
# Garden District          -79.377114             1.204510        1.174703
# Grange Park              -79.392319             1.123206        1.192123
# Harbord Village          -79.409745             1.164493        1.121693
# Harbourfront / CityPlace -79.380150             1.050434        1.313884
# Kensington Market        -79.402260             1.299365        1.072498
# Milliken                 -79.301763             1.006521        1.584251
# Newtonbrook              -79.425679             1.003740        1.806241
# Niagara                  -79.408698             1.192869        1.135729
# Yorkville                -79.390168             1.189265        1.124850
#
#                           Average Income pro  frequency inv
# Name
# Agincourt                           1.070869       1.438596
# Alexandra Park                      1.000000       1.242105
# Bay Street Corridor                 1.244424       1.172414
# Christie Pits                       1.127046       1.885167
# Church and Wellesley                1.210001       1.338346
# Discovery District                  1.260789       1.157895
# Fashion District                    1.509573       1.172414
# Financial District                  1.517405       1.078236
# Garden District                     1.209545       1.087719
# Grange Park                         1.182228       1.000000
# Harbord Village                     1.305136       1.368421
# Harbourfront / CityPlace            1.579121       1.639098
# Kensington Market                   1.042641       1.044929
# Milliken                            1.064943       1.708502
# Newtonbrook                         1.160616       2.000000
# Niagara                             1.291332       1.885167
# Yorkville                           2.000000       1.204678

# %%
sliced_df.sort_values(by='potential', ascending=False)
# Out:
#                           Population  Land area (km2)  Density (people/km2)  \
# Name
# Newtonbrook                    36046             8.77                  4110
# Harbourfront / CityPlace       14368             1.87                  9228
# Niagara                         6524             0.55                 11862
# Yorkville                       6045             0.56                 10795
# Bay Street Corridor             4787             0.11                 43518
# Agincourt                      44577            12.45                  3580
# Milliken                       26272             7.19                  3654
# Christie Pits                   5124             0.64                  8006
# Church and Wellesley           13397             0.55                 24358
# Harbord Village                 5906             0.64                  9228
# Fashion District                4642             0.98                  4737
# Financial District               548             0.47                  1166
# Discovery District              7262             0.66                  6998
# Garden District                 8240             0.52                 15846
# Alexandra Park                  4355             0.32                 13609
# Grange Park                     9007             0.84                 10793
# Kensington Market               3740             0.36                 10389
#
#                           Average Income  frequency  potential   latitude  \
# Name
# Newtonbrook                        33428         10   4.208387  43.793886
# Harbourfront / CityPlace           69232         14   3.572285  43.640080
# Niagara                            44611         11   3.298033  43.644075
# Yorkville                         105239         27   3.223104  43.671386
# Bay Street Corridor                40598         29   3.198895  43.667342
# Agincourt                          25750         18   3.081097  43.785353
# Milliken                           25243         13   2.901275  43.823174
# Christie Pits                      30556         11   2.731306  43.667139
# Church and Wellesley               37653         21   2.495469  43.665524
# Harbord Village                    45792         20   2.332847  43.661522
# Fashion District                   63282         29   2.136232  43.645456
# Financial District                 63952         37   2.007871  43.648664
# Discovery District                 41998         30   1.950390  43.657556
# Garden District                    37614         36   1.861562  43.656500
# Alexandra Park                     19687         25   1.805503  43.650787
# Grange Park                        35277         48   1.583003  43.652197
# Kensington Market                  23335         41   1.518271  43.655214
#
#                           longitude  Land area (km2) inv  Population pro  \
# Name
# Newtonbrook              -79.425679             1.003740        1.806241
# Harbourfront / CityPlace -79.380150             1.050434        1.313884
# Niagara                  -79.408698             1.192869        1.135729
# Yorkville                -79.390168             1.189265        1.124850
# Bay Street Corridor      -79.388457             2.000000        1.096277
# Agincourt                -79.278549             1.000000        2.000000
# Milliken                 -79.301763             1.006521        1.584251
# Christie Pits            -79.422766             1.164493        1.103931
# Church and Wellesley     -79.383801             1.192869        1.291830
# Harbord Village          -79.409745             1.164493        1.121693
# Fashion District         -79.394994             1.104331        1.092984
# Financial District       -79.381540             1.227215        1.000000
# Discovery District       -79.389480             1.159238        1.152490
# Garden District          -79.377114             1.204510        1.174703
# Alexandra Park           -79.404318             1.337900        1.086466
# Grange Park              -79.392319             1.123206        1.192123
# Kensington Market        -79.402260             1.299365        1.072498
#
#                           Average Income pro  frequency inv
# Name
# Newtonbrook                         1.160616       2.000000
# Harbourfront / CityPlace            1.579121       1.639098
# Niagara                             1.291332       1.885167
# Yorkville                           2.000000       1.204678
# Bay Street Corridor                 1.244424       1.172414
# Agincourt                           1.070869       1.438596
# Milliken                            1.064943       1.708502
# Christie Pits                       1.127046       1.885167
# Church and Wellesley                1.210001       1.338346
# Harbord Village                     1.305136       1.368421
# Fashion District                    1.509573       1.172414
# Financial District                  1.517405       1.078236
# Discovery District                  1.260789       1.157895
# Garden District                     1.209545       1.087719
# Alexandra Park                      1.000000       1.242105
# Grange Park                         1.182228       1.000000
# Kensington Market                   1.042641       1.044929

# %% [markdown]
# <h3> Create the final map with this transformed potential -

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=13.5)    # center point of the map

for lat, lng, label, pot in zip(sliced_df['latitude'], sliced_df['longitude'], sliced_df.index.values, sliced_df['potential']):
    label = folium.Popup(label, parse_html=True)
    folium.Circle(    # attributes of each bubble in the map
        [lat, lng],
        radius=pot*200,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h2> Some Observations: </h2>
#
#     If one wishes to open a retaurant anywhere in Toronto, Newtonbrook is the place for them. It has a significant population with decent per capita income and relatively low number of pre-existing restaurants!
#
#     However, if one insists on opening a restaurant in downtown Toronto because of tourist attractions and networking, Harbourfront(City Place) is the optimum location. If one wants to open a restaurant with lowest risk of failure, i.e. a place where many restaurants are known to flourish, Bay street corridor is the optimum location. Basically, any end-user using this model can apply their own filters on the final results according to their needs and wishes and the model will give them the optimum location leveraging which parameters they value and which they don't. Cool!

# %% [markdown]
# <h2> Clustering:</h2>
#
#     Now that we have individual data points readily available, we can find optimal locations as per our needs from the analysis above. Extending this idea, we can create clusters of all these locations to find out which of them are similar and in what way. This will further help us in combining our analytical findings with geospatial data!

# %% [markdown]
# <h3> create a new dataframe, cutting off all the unwanted/repeated parameters -

# %%
refined_data = sliced_df.iloc[:, 5:]
refined_data
# Out:
#                           potential   latitude  longitude  \
# Name
# Agincourt                  3.081097  43.785353 -79.278549
# Alexandra Park             1.805503  43.650787 -79.404318
# Bay Street Corridor        3.198895  43.667342 -79.388457
# Christie Pits              2.731306  43.667139 -79.422766
# Church and Wellesley       2.495469  43.665524 -79.383801
# Discovery District         1.950390  43.657556 -79.389480
# Fashion District           2.136232  43.645456 -79.394994
# Financial District         2.007871  43.648664 -79.381540
# Garden District            1.861562  43.656500 -79.377114
# Grange Park                1.583003  43.652197 -79.392319
# Harbord Village            2.332847  43.661522 -79.409745
# Harbourfront / CityPlace   3.572285  43.640080 -79.380150
# Kensington Market          1.518271  43.655214 -79.402260
# Milliken                   2.901275  43.823174 -79.301763
# Newtonbrook                4.208387  43.793886 -79.425679
# Niagara                    3.298033  43.644075 -79.408698
# Yorkville                  3.223104  43.671386 -79.390168
#
#                           Land area (km2) inv  Population pro  \
# Name
# Agincourt                            1.000000        2.000000
# Alexandra Park                       1.337900        1.086466
# Bay Street Corridor                  2.000000        1.096277
# Christie Pits                        1.164493        1.103931
# Church and Wellesley                 1.192869        1.291830
# Discovery District                   1.159238        1.152490
# Fashion District                     1.104331        1.092984
# Financial District                   1.227215        1.000000
# Garden District                      1.204510        1.174703
# Grange Park                          1.123206        1.192123
# Harbord Village                      1.164493        1.121693
# Harbourfront / CityPlace             1.050434        1.313884
# Kensington Market                    1.299365        1.072498
# Milliken                             1.006521        1.584251
# Newtonbrook                          1.003740        1.806241
# Niagara                              1.192869        1.135729
# Yorkville                            1.189265        1.124850
#
#                           Average Income pro  frequency inv
# Name
# Agincourt                           1.070869       1.438596
# Alexandra Park                      1.000000       1.242105
# Bay Street Corridor                 1.244424       1.172414
# Christie Pits                       1.127046       1.885167
# Church and Wellesley                1.210001       1.338346
# Discovery District                  1.260789       1.157895
# Fashion District                    1.509573       1.172414
# Financial District                  1.517405       1.078236
# Garden District                     1.209545       1.087719
# Grange Park                         1.182228       1.000000
# Harbord Village                     1.305136       1.368421
# Harbourfront / CityPlace            1.579121       1.639098
# Kensington Market                   1.042641       1.044929
# Milliken                            1.064943       1.708502
# Newtonbrook                         1.160616       2.000000
# Niagara                             1.291332       1.885167
# Yorkville                           2.000000       1.204678

# %% [markdown]
# <h3> Import the KMeans library and fit the scaled version of our parameters -

# %%
from sklearn.cluster import KMeans    # import KMeans

x = refined_data.iloc[:, 3:]
k_means = KMeans(init='k-means++', n_clusters=4, n_init=15).fit(x)    # fit x
k_means.labels_
# Out:
# array([1, 0, 0, 2, 0, 0, 0, 0, 0, 0, 0, 2, 0, 1, 1, 2, 3], dtype=int32)

# %% [markdown]
# <h3> Add these labels to (refined_data) -

# %%
refined_data['label'] = k_means.labels_
refined_data.sort_values(by='potential', ascending=False)
# Out:
#                           potential   latitude  longitude  \
# Name
# Newtonbrook                4.208387  43.793886 -79.425679
# Harbourfront / CityPlace   3.572285  43.640080 -79.380150
# Niagara                    3.298033  43.644075 -79.408698
# Yorkville                  3.223104  43.671386 -79.390168
# Bay Street Corridor        3.198895  43.667342 -79.388457
# Agincourt                  3.081097  43.785353 -79.278549
# Milliken                   2.901275  43.823174 -79.301763
# Christie Pits              2.731306  43.667139 -79.422766
# Church and Wellesley       2.495469  43.665524 -79.383801
# Harbord Village            2.332847  43.661522 -79.409745
# Fashion District           2.136232  43.645456 -79.394994
# Financial District         2.007871  43.648664 -79.381540
# Discovery District         1.950390  43.657556 -79.389480
# Garden District            1.861562  43.656500 -79.377114
# Alexandra Park             1.805503  43.650787 -79.404318
# Grange Park                1.583003  43.652197 -79.392319
# Kensington Market          1.518271  43.655214 -79.402260
#
#                           Land area (km2) inv  Population pro  \
# Name
# Newtonbrook                          1.003740        1.806241
# Harbourfront / CityPlace             1.050434        1.313884
# Niagara                              1.192869        1.135729
# Yorkville                            1.189265        1.124850
# Bay Street Corridor                  2.000000        1.096277
# Agincourt                            1.000000        2.000000
# Milliken                             1.006521        1.584251
# Christie Pits                        1.164493        1.103931
# Church and Wellesley                 1.192869        1.291830
# Harbord Village                      1.164493        1.121693
# Fashion District                     1.104331        1.092984
# Financial District                   1.227215        1.000000
# Discovery District                   1.159238        1.152490
# Garden District                      1.204510        1.174703
# Alexandra Park                       1.337900        1.086466
# Grange Park                          1.123206        1.192123
# Kensington Market                    1.299365        1.072498
#
#                           Average Income pro  frequency inv  label
# Name
# Newtonbrook                         1.160616       2.000000      1
# Harbourfront / CityPlace            1.579121       1.639098      2
# Niagara                             1.291332       1.885167      2
# Yorkville                           2.000000       1.204678      3
# Bay Street Corridor                 1.244424       1.172414      0
# Agincourt                           1.070869       1.438596      1
# Milliken                            1.064943       1.708502      1
# Christie Pits                       1.127046       1.885167      2
# Church and Wellesley                1.210001       1.338346      0
# Harbord Village                     1.305136       1.368421      0
# Fashion District                    1.509573       1.172414      0
# Financial District                  1.517405       1.078236      0
# Discovery District                  1.260789       1.157895      0
# Garden District                     1.209545       1.087719      0
# Alexandra Park                      1.000000       1.242105      0
# Grange Park                         1.182228       1.000000      0
# Kensington Market                   1.042641       1.044929      0

# %% [markdown]
# <h3> Map this dataframe with each location's color scheme depending on its label -

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13.5)

kclusters = 4

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, pot in zip(refined_data['latitude'], refined_data['longitude'], refined_data.index.values, refined_data['label'], refined_data['potential']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=pot*200,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3> Let's now look at each label(cluster) individually -

# %%
def highlight(s):    # to add background colour to dataframes as per their label numbers (row wise)
    index = int(s[-1] - 1)
    return ['background-color: {}'.format(rainbow[index]) for _ in s]

def highlight_col(s):    # # to add background colour to dataframes as per their label numbers (column wise)
    if s[0]=='-':
        return ['' for _ in s]
    else:
        index = int(s[0] - 1)
        return ['background-color: {}'.format(rainbow[index]) for _ in s]

# %%
# cluster 0 points:
zero_df = sliced_df[refined_data['label'] == 0].iloc[:, :6]
zero_df['label'] = refined_data['label']
zero_df.style.apply(highlight, axis=1)
# Out:
# <style  type="text/css" >
#     #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow0_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow0_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow0_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow0_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow0_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow0_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow0_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow1_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow1_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow1_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow1_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow1_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow1_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow1_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow2_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow2_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow2_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow2_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow2_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow2_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow2_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow3_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow3_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow3_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow3_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow3_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow3_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow3_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow4_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow4_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow4_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow4_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow4_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow4_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow4_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow5_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow5_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow5_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow5_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow5_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow5_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow5_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow6_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow6_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow6_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow6_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow6_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow6_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow6_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow7_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow7_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow7_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow7_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow7_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow7_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow7_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow8_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow8_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow8_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow8_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow8_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow8_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow8_col6 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow9_col0 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow9_col1 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow9_col2 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow9_col3 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow9_col4 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow9_col5 {
#             background-color:  #ff0000;
#         }    #T_b9b6efac_ada4_11ea_a1a9_f768643ae07brow9_col6 {
#             background-color:  #ff0000;
#         }</style><table id="T_b9b6efac_ada4_11ea_a1a9_f768643ae07b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Population</th>        <th class="col_heading level0 col1" >Land area (km2)</th>        <th class="col_heading level0 col2" >Density (people/km2)</th>        <th class="col_heading level0 col3" >Average Income</th>        <th class="col_heading level0 col4" >frequency</th>        <th class="col_heading level0 col5" >potential</th>        <th class="col_heading level0 col6" >label</th>    </tr>    <tr>        <th class="index_name level0" >Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="

# %%
# cluster 1 points:
one_df = sliced_df[refined_data['label'] == 1].iloc[:, :6]
one_df['label'] = refined_data['label']
one_df.style.apply(highlight, axis=1)
# Out:
# <style  type="text/css" >
#     #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col0 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col1 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col2 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col3 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col4 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col5 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col6 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col0 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col1 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col2 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col3 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col4 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col5 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col6 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col0 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col1 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col2 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col3 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col4 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col5 {
#             background-color:  #8000ff;
#         }    #T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col6 {
#             background-color:  #8000ff;
#         }</style><table id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Population</th>        <th class="col_heading level0 col1" >Land area (km2)</th>        <th class="col_heading level0 col2" >Density (people/km2)</th>        <th class="col_heading level0 col3" >Average Income</th>        <th class="col_heading level0 col4" >frequency</th>        <th class="col_heading level0 col5" >potential</th>        <th class="col_heading level0 col6" >label</th>    </tr>    <tr>        <th class="index_name level0" >Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07blevel0_row0" class="row_heading level0 row0" >Agincourt</th>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col0" class="data row0 col0" >44577</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col1" class="data row0 col1" >12.45</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col2" class="data row0 col2" >3580</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col3" class="data row0 col3" >25750</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col4" class="data row0 col4" >18</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col5" class="data row0 col5" >3.0811</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow0_col6" class="data row0 col6" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07blevel0_row1" class="row_heading level0 row1" >Milliken</th>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col0" class="data row1 col0" >26272</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col1" class="data row1 col1" >7.19</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col2" class="data row1 col2" >3654</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col3" class="data row1 col3" >25243</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col4" class="data row1 col4" >13</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col5" class="data row1 col5" >2.90127</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow1_col6" class="data row1 col6" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07blevel0_row2" class="row_heading level0 row2" >Newtonbrook</th>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col0" class="data row2 col0" >36046</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col1" class="data row2 col1" >8.77</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col2" class="data row2 col2" >4110</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col3" class="data row2 col3" >33428</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col4" class="data row2 col4" >10</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col5" class="data row2 col5" >4.20839</td>
#                         <td id="T_bcf2452c_ada4_11ea_a1a9_f768643ae07brow2_col6" class="data row2 col6" >1</td>
#             </tr>
#     </tbody></table>

# %%
# cluster 2 points:
two_df = sliced_df[refined_data['label'] == 2].iloc[:, :6]
two_df['label'] = refined_data['label']
two_df.style.apply(highlight, axis=1)
# Out:
# <style  type="text/css" >
#     #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col0 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col1 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col2 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col3 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col4 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col5 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col6 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col0 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col1 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col2 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col3 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col4 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col5 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col6 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col0 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col1 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col2 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col3 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col4 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col5 {
#             background-color:  #2adddd;
#         }    #T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col6 {
#             background-color:  #2adddd;
#         }</style><table id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Population</th>        <th class="col_heading level0 col1" >Land area (km2)</th>        <th class="col_heading level0 col2" >Density (people/km2)</th>        <th class="col_heading level0 col3" >Average Income</th>        <th class="col_heading level0 col4" >frequency</th>        <th class="col_heading level0 col5" >potential</th>        <th class="col_heading level0 col6" >label</th>    </tr>    <tr>        <th class="index_name level0" >Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07blevel0_row0" class="row_heading level0 row0" >Christie Pits</th>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col0" class="data row0 col0" >5124</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col1" class="data row0 col1" >0.64</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col2" class="data row0 col2" >8006</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col3" class="data row0 col3" >30556</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col4" class="data row0 col4" >11</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col5" class="data row0 col5" >2.73131</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07blevel0_row1" class="row_heading level0 row1" >Harbourfront / CityPlace</th>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col0" class="data row1 col0" >14368</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col1" class="data row1 col1" >1.87</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col2" class="data row1 col2" >9228</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col3" class="data row1 col3" >69232</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col4" class="data row1 col4" >14</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col5" class="data row1 col5" >3.57229</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow1_col6" class="data row1 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07blevel0_row2" class="row_heading level0 row2" >Niagara</th>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col0" class="data row2 col0" >6524</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col1" class="data row2 col1" >0.55</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col2" class="data row2 col2" >11862</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col3" class="data row2 col3" >44611</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col4" class="data row2 col4" >11</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col5" class="data row2 col5" >3.29803</td>
#                         <td id="T_bea05bd4_ada4_11ea_a1a9_f768643ae07brow2_col6" class="data row2 col6" >2</td>
#             </tr>
#     </tbody></table>

# %%
# cluster 3 points:
three_df = sliced_df[refined_data['label'] == 3].iloc[:, :6]
three_df['label'] = refined_data['label']
three_df.style.apply(highlight, axis=1)
# Out:
# <style  type="text/css" >
#     #T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col0 {
#             background-color:  #d4dd80;
#         }    #T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col1 {
#             background-color:  #d4dd80;
#         }    #T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col2 {
#             background-color:  #d4dd80;
#         }    #T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col3 {
#             background-color:  #d4dd80;
#         }    #T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col4 {
#             background-color:  #d4dd80;
#         }    #T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col5 {
#             background-color:  #d4dd80;
#         }    #T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col6 {
#             background-color:  #d4dd80;
#         }</style><table id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Population</th>        <th class="col_heading level0 col1" >Land area (km2)</th>        <th class="col_heading level0 col2" >Density (people/km2)</th>        <th class="col_heading level0 col3" >Average Income</th>        <th class="col_heading level0 col4" >frequency</th>        <th class="col_heading level0 col5" >potential</th>        <th class="col_heading level0 col6" >label</th>    </tr>    <tr>        <th class="index_name level0" >Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07blevel0_row0" class="row_heading level0 row0" >Yorkville</th>
#                         <td id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col0" class="data row0 col0" >6045</td>
#                         <td id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col1" class="data row0 col1" >0.56</td>
#                         <td id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col2" class="data row0 col2" >10795</td>
#                         <td id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col3" class="data row0 col3" >105239</td>
#                         <td id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col4" class="data row0 col4" >27</td>
#                         <td id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col5" class="data row0 col5" >3.2231</td>
#                         <td id="T_bfeef00e_ada4_11ea_a1a9_f768643ae07brow0_col6" class="data row0 col6" >3</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <h3> Let's look at the stats of all these clusters together in one dataframe -

# %%
summary_df = sliced_df.iloc[:, :6].describe().iloc[1, :].to_frame()
summary_df['Cluster 0'] = zero_df.describe().iloc[1, :]
summary_df['Cluster 1'] = one_df.describe().iloc[1, :]
summary_df['Cluster 2'] = two_df.describe().iloc[1, :]
summary_df['Cluster 3'] = three_df.describe().iloc[1, :]

labels = pd.DataFrame({'mean': ['-'], 'Cluster 0': [0], 'Cluster 1': [1], 'Cluster 2': [2], 'Cluster 3': [3]})
labels.set_axis(['label'], inplace=True)

counts = pd.DataFrame({'mean': [sliced_df.shape[0]], 'Cluster 0': [zero_df.shape[0]], 'Cluster 1': [one_df.shape[0]], 'Cluster 2': [two_df.shape[0]], 'Cluster 3': [three_df.shape[0]]})
counts.set_axis(['count'], inplace=True)

summary_df = pd.concat([labels, counts, summary_df])
summary_df.style.apply(highlight_col, axis=0)
# Out:
# <style  type="text/css" >
#     #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col4 {
#             background-color:  #d4dd80;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col4 {
#             background-color:  #d4dd80;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col4 {
#             background-color:  #d4dd80;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col4 {
#             background-color:  #d4dd80;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col4 {
#             background-color:  #d4dd80;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow5_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow5_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow5_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow5_col4 {
#             background-color:  #d4dd80;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow6_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow6_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow6_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow6_col4 {
#             background-color:  #d4dd80;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow7_col1 {
#             background-color:  #ff0000;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow7_col2 {
#             background-color:  #8000ff;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow7_col3 {
#             background-color:  #2adddd;
#         }    #T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow7_col4 {
#             background-color:  #d4dd80;
#         }</style><table id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >mean</th>        <th class="col_heading level0 col1" >Cluster 0</th>        <th class="col_heading level0 col2" >Cluster 1</th>        <th class="col_heading level0 col3" >Cluster 2</th>        <th class="col_heading level0 col4" >Cluster 3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07blevel0_row0" class="row_heading level0 row0" >label</th>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col0" class="data row0 col0" >-</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col3" class="data row0 col3" >2</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow0_col4" class="data row0 col4" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07blevel0_row1" class="row_heading level0 row1" >count</th>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col0" class="data row1 col0" >17</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col1" class="data row1 col1" >10</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col2" class="data row1 col2" >3</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col3" class="data row1 col3" >3</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow1_col4" class="data row1 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07blevel0_row2" class="row_heading level0 row2" >Population</th>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col0" class="data row2 col0" >11814.1</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col1" class="data row2 col1" >6188.4</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col2" class="data row2 col2" >35631.7</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col3" class="data row2 col3" >8672</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow2_col4" class="data row2 col4" >6045</td>
#             </tr>
#             <tr>
#                         <th id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07blevel0_row3" class="row_heading level0 row3" >Land area (km2)</th>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col0" class="data row3 col0" >2.20471</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col1" class="data row3 col1" >0.545</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col2" class="data row3 col2" >9.47</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col3" class="data row3 col3" >1.02</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow3_col4" class="data row3 col4" >0.56</td>
#             </tr>
#             <tr>
#                         <th id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07blevel0_row4" class="row_heading level0 row4" >Density (people/km2)</th>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col0" class="data row4 col0" >11286.9</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col1" class="data row4 col1" >14064.2</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col2" class="data row4 col2" >3781.33</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col3" class="data row4 col3" >9698.67</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow4_col4" class="data row4 col4" >10795</td>
#             </tr>
#             <tr>
#                         <th id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07blevel0_row5" class="row_heading level0 row5" >Average Income</th>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow5_col0" class="data row5 col0" >43720.4</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow5_col1" class="data row5 col1" >40918.8</td>
#                         <td id="T_c1cd1996_ada4_11ea_a1a9_f768643ae07brow5_col2" class="data row5 col2" >28140.3

# %% [markdown]
# <h2> Clustered Groups: </h2>
#
#    <h3>Group 0:</h3>
#
#     Places with low population, extremely low area, below average per-capita income with large number of pre-existing restaurants. Overall, these places have pretty low potential for opening up a new restaurant.
#
#    <h3>Group 1:</h3>
#
#     Places with very high population & even higher area, low per-capita income with low number of pre-existing restaraunts. Overall, these places have pretty high potential for opening up a new restaurant. Having said that, these places are located in relatively remote areas and thus networking and transportation might be an issue.
#
#    <h3>Group 2:</h3>
#
#     Places with slightly below average population & area, above average per-capita income with low number of pre-existing restaraunts. Overall, these places have pretty high potential for opening up a new restaurant.
#
#    <h3>Group 3:</h3>
#
#     This group only has one place, an outlier with extremely low population & area, exceptionally high per-capita income with large number of pre-existing restaurants. Though this place does have a high potential, this analysis might not model this place well, you know, this place being an outlier and everything.
